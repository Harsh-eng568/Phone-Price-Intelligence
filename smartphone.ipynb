# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv(r'C:\Users\hband\Downloads\smartphones - smartphones.csv')
df.head()
# Out:
#                        model    price  rating  \
# 0              OnePlus 11 5G  ₹54,999    89.0
# 1  OnePlus Nord CE 2 Lite 5G  ₹19,989    81.0
# 2      Samsung Galaxy A14 5G  ₹16,499    75.0
# 3       Motorola Moto G62 5G  ₹14,999    81.0
# 4         Realme 10 Pro Plus  ₹24,999    82.0
#
#                                        sim  \
# 0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 1       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 2       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 3       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 4       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
#
#                                          processor                        ram  \
# 0  Snapdragon 8 Gen2, Octa Core, 3.2 GHz Processor  12 GB RAM, 256 GB inbuilt
# 1     Snapdragon 695, Octa Core, 2.2 GHz Processor   6 GB RAM, 128 GB inbuilt
# 2        Exynos 1330, Octa Core, 2.4 GHz Processor    4 GB RAM, 64 GB inbuilt
# 3    Snapdragon  695, Octa Core, 2.2 GHz Processor   6 GB RAM, 128 GB inbuilt
# 4     Dimensity 1080, Octa Core, 2.6 GHz Processor   6 GB RAM, 128 GB inbuilt
#
#                                     battery  \
# 0  5000 mAh Battery with 100W Fast Charging
# 1   5000 mAh Battery with 33W Fast Charging
# 2   5000 mAh Battery with 15W Fast Charging
# 3       5000 mAh Battery with Fast Charging
# 4   5000 mAh Battery with 67W Fast Charging
#
#                                              display  \
# 0  6.7 inches, 1440 x 3216 px, 120 Hz Display wit...
# 1  6.59 inches, 1080 x 2412 px, 120 Hz Display wi...
# 2  6.6 inches, 1080 x 2408 px, 90 Hz Display with...
# 3  6.55 inches, 1080 x 2400 px, 120 Hz Display wi...
# 4  6.7 inches, 1080 x 2412 px, 120 Hz Display wit...
#
#                                               camera  \
# 0  50 MP + 48 MP + 32 MP Triple Rear & 16 MP Fron...
# 1  64 MP + 2 MP + 2 MP Triple Rear & 16 MP Front ...
# 2  50 MP + 2 MP + 2 MP Triple Rear & 13 MP Front ...
# 3  50 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 4  108 MP + 8 MP + 2 MP Triple Rear & 16 MP Front...
#
#                                card           os
# 0         Memory Card Not Supported  Android v13
# 1   Memory Card (Hybrid), upto 1 TB  Android v12
# 2  Memory Card Supported, upto 1 TB  Android v13
# 3   Memory Card (Hybrid), upto 1 TB  Android v12
# 4         Memory Card Not Supported  Android v13

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1020 entries, 0 to 1019
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   model      1020 non-null   object
#  1   price      1020 non-null   object
#  2   rating     879 non-null    float64
#  3   sim        1020 non-null   object
#  4   processor  1020 non-null   object
#  5   ram        1020 non-null   object
#  6   battery    1020 non-null   object
#  7   display    1020 non-null   object
#  8   camera     1019 non-null   object
#  9   card       1013 non-null   object
#  10  os         1003 non-null   object
# dtypes: float64(1), object(10)
# memory usage: 87.8+ KB

# %%
df.describe()
# Out:
#            rating
# count  879.000000
# mean    78.258248
# std      7.402854
# min     60.000000
# 25%     74.000000
# 50%     80.000000
# 75%     84.000000
# max     89.000000

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df1 = df.copy()
df1['price']
# Out:
# 0       ₹54,999
# 1       ₹19,989
# 2       ₹16,499
# 3       ₹14,999
# 4       ₹24,999
#          ...
# 1015    ₹34,990
# 1016    ₹14,990
# 1017    ₹28,990
# 1018    ₹19,990
# 1019    ₹24,990
# Name: price, Length: 1020, dtype: object

# %%
df1['price'] = df1['price'].astype(str).str.replace('₹','').str.replace(',','').astype(int)

# %%
df1 = df1.reset_index()
df1
# Out:
#       index                            model  price  rating  \
# 0         0                    OnePlus 11 5G  54999    89.0
# 1         1        OnePlus Nord CE 2 Lite 5G  19989    81.0
# 2         2            Samsung Galaxy A14 5G  16499    75.0
# 3         3             Motorola Moto G62 5G  14999    81.0
# 4         4               Realme 10 Pro Plus  24999    82.0
# ...     ...                              ...    ...     ...
# 1015   1015       Motorola Moto Edge S30 Pro  34990    83.0
# 1016   1016                      Honor X8 5G  14990    75.0
# 1017   1017  POCO X4 GT 5G (8GB RAM + 256GB)  28990    85.0
# 1018   1018             Motorola Moto G91 5G  19990    80.0
# 1019   1019           Samsung Galaxy M52s 5G  24990    74.0
#
#                                                     sim  \
# 0               Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 1                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 2                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 3                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 4                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# ...                                                 ...
# 1015                 Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 1016                 Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 1017  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...
# 1018            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 1019                 Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
#
#                                             processor  \
# 0     Snapdragon 8 Gen2, Octa Core, 3.2 GHz Processor
# 1        Snapdragon 695, Octa Core, 2.2 GHz Processor
# 2           Exynos 1330, Octa Core, 2.4 GHz Processor
# 3       Snapdragon  695, Octa Core, 2.2 GHz Processor
# 4        Dimensity 1080, Octa Core, 2.6 GHz Processor
# ...                                               ...
# 1015    Snapdragon 8 Gen1, Octa Core, 3 GHz Processor
# 1016   Snapdragon  480+, Octa Core, 2.2 GHz Processor
# 1017    Dimensity 8100, Octa Core, 2.85 GHz Processor
# 1018     Snapdragon 695, Octa Core, 2.2 GHz Processor
# 1019                              Octa Core Processor
#
#                             ram                                    battery  \
# 0     12 GB RAM, 256 GB inbuilt   5000 mAh Battery with 100W Fast Charging
# 1      6 GB RAM, 128 GB inbuilt    5000 mAh Battery with 33W Fast Charging
# 2       4 GB RAM, 64 GB inbuilt    5000 mAh Battery with 15W Fast Charging
# 3      6 GB RAM, 128 GB inbuilt        5000 mAh Battery with Fast Charging
# 4      6 GB RAM, 128 GB inbuilt    5000 mAh Battery with 67W Fast Charging
# ...                         ...                                        ...
# 1015   8 GB RAM, 128 GB inbuilt  5000 mAh Battery with 68.2W Fast Charging
# 1016   6 GB RAM, 128 GB inbuilt  5000 mAh Battery with 22.5W Fast Charging
# 1017   8 GB RAM, 256 GB inbuilt    5080 mAh Battery with 67W Fast Charging
# 1018   6 GB RAM, 128 GB inbuilt        5000 mAh Battery with Fast Charging
# 1019   8 GB RAM, 128 GB inbuilt        5000 mAh Battery with Fast Charging
#
#                                                 display  \
# 0     6.7 inches, 1440 x 3216 px, 120 Hz Display wit...
# 1     6.59 inches, 1080 x 2412 px, 120 Hz Display wi...
# 2     6.6 inches, 1080 x 2408 px, 90 Hz Display with...
# 3     6.55 inches, 1080 x 2400 px, 120 Hz Display wi...
# 4     6.7 inches, 1080 x 2412 px, 120 Hz Display wit...
# ...                                                 ...
# 1015  6.67 inches, 1080 x 2460 px, 120 Hz Display wi...
# 1016  6.5 inches, 720 x 1600 px Display with Water D...
# 1017  6.6 inches, 1080 x 2460 px, 144 Hz Display wit...
# 1018  6.8 inches, 1080 x 2400 px Display with Punch ...
# 1019  6.5 inches, 1080 x 2400 px Display with Water ...
#
#                                                  camera  \
# 0     50 MP + 48 MP + 32 MP Triple Rear & 16 MP Fron...
# 1     64 MP + 2 MP + 2 MP Triple Rear & 16 MP Front ...
# 2     50 MP + 2 MP + 2 MP Triple Rear & 13 MP Front ...
# 3     50 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 4     108 MP + 8 MP + 2 MP Triple Rear & 16 MP Front...
# ...                                                 ...
# 1015  64 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 1016  48 MP + 2 MP + Depth Sensor Triple Rear & 8 MP...
# 1017  64 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 1018  108 MP + 8 MP + 2 MP Triple Rear & 32 MP Front...
# 1019  64 MP + 8 MP + 5 MP Triple Rear & 32 MP Front ...
#
#                                   card           os
# 0            Memory Card Not Supported  Android v13
# 1      Memory Card (Hybrid), upto 1 TB  Android v12
# 2     Memory Card Supported, upto 1 TB  Android v13
# 3      Memory Card (Hybrid), upto 1 TB  Android v12
# 4            Memory Card Not Supported  Android v13
# ...                                ...          ...
# 1015                       Android v12  No FM Radio
# 1016  Memory Card Supported, upto 1 TB  Android v11
# 1017         Memory Card Not Supported  Android v12
# 1018  Memory Card Supported, upto 1 TB  Android v12
# 1019  Memory Card Supported, upto 1 TB  Android v12
#
# [1020 rows x 12 columns]

# %%
df1['index'] = df1['index'] + 2
df1
# Out:
#       index                            model  price  rating  \
# 0         2                    OnePlus 11 5G  54999    89.0
# 1         3        OnePlus Nord CE 2 Lite 5G  19989    81.0
# 2         4            Samsung Galaxy A14 5G  16499    75.0
# 3         5             Motorola Moto G62 5G  14999    81.0
# 4         6               Realme 10 Pro Plus  24999    82.0
# ...     ...                              ...    ...     ...
# 1015   1017       Motorola Moto Edge S30 Pro  34990    83.0
# 1016   1018                      Honor X8 5G  14990    75.0
# 1017   1019  POCO X4 GT 5G (8GB RAM + 256GB)  28990    85.0
# 1018   1020             Motorola Moto G91 5G  19990    80.0
# 1019   1021           Samsung Galaxy M52s 5G  24990    74.0
#
#                                                     sim  \
# 0               Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 1                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 2                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 3                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 4                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# ...                                                 ...
# 1015                 Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 1016                 Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 1017  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...
# 1018            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 1019                 Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
#
#                                             processor  \
# 0     Snapdragon 8 Gen2, Octa Core, 3.2 GHz Processor
# 1        Snapdragon 695, Octa Core, 2.2 GHz Processor
# 2           Exynos 1330, Octa Core, 2.4 GHz Processor
# 3       Snapdragon  695, Octa Core, 2.2 GHz Processor
# 4        Dimensity 1080, Octa Core, 2.6 GHz Processor
# ...                                               ...
# 1015    Snapdragon 8 Gen1, Octa Core, 3 GHz Processor
# 1016   Snapdragon  480+, Octa Core, 2.2 GHz Processor
# 1017    Dimensity 8100, Octa Core, 2.85 GHz Processor
# 1018     Snapdragon 695, Octa Core, 2.2 GHz Processor
# 1019                              Octa Core Processor
#
#                             ram                                    battery  \
# 0     12 GB RAM, 256 GB inbuilt   5000 mAh Battery with 100W Fast Charging
# 1      6 GB RAM, 128 GB inbuilt    5000 mAh Battery with 33W Fast Charging
# 2       4 GB RAM, 64 GB inbuilt    5000 mAh Battery with 15W Fast Charging
# 3      6 GB RAM, 128 GB inbuilt        5000 mAh Battery with Fast Charging
# 4      6 GB RAM, 128 GB inbuilt    5000 mAh Battery with 67W Fast Charging
# ...                         ...                                        ...
# 1015   8 GB RAM, 128 GB inbuilt  5000 mAh Battery with 68.2W Fast Charging
# 1016   6 GB RAM, 128 GB inbuilt  5000 mAh Battery with 22.5W Fast Charging
# 1017   8 GB RAM, 256 GB inbuilt    5080 mAh Battery with 67W Fast Charging
# 1018   6 GB RAM, 128 GB inbuilt        5000 mAh Battery with Fast Charging
# 1019   8 GB RAM, 128 GB inbuilt        5000 mAh Battery with Fast Charging
#
#                                                 display  \
# 0     6.7 inches, 1440 x 3216 px, 120 Hz Display wit...
# 1     6.59 inches, 1080 x 2412 px, 120 Hz Display wi...
# 2     6.6 inches, 1080 x 2408 px, 90 Hz Display with...
# 3     6.55 inches, 1080 x 2400 px, 120 Hz Display wi...
# 4     6.7 inches, 1080 x 2412 px, 120 Hz Display wit...
# ...                                                 ...
# 1015  6.67 inches, 1080 x 2460 px, 120 Hz Display wi...
# 1016  6.5 inches, 720 x 1600 px Display with Water D...
# 1017  6.6 inches, 1080 x 2460 px, 144 Hz Display wit...
# 1018  6.8 inches, 1080 x 2400 px Display with Punch ...
# 1019  6.5 inches, 1080 x 2400 px Display with Water ...
#
#                                                  camera  \
# 0     50 MP + 48 MP + 32 MP Triple Rear & 16 MP Fron...
# 1     64 MP + 2 MP + 2 MP Triple Rear & 16 MP Front ...
# 2     50 MP + 2 MP + 2 MP Triple Rear & 13 MP Front ...
# 3     50 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 4     108 MP + 8 MP + 2 MP Triple Rear & 16 MP Front...
# ...                                                 ...
# 1015  64 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 1016  48 MP + 2 MP + Depth Sensor Triple Rear & 8 MP...
# 1017  64 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 1018  108 MP + 8 MP + 2 MP Triple Rear & 32 MP Front...
# 1019  64 MP + 8 MP + 5 MP Triple Rear & 32 MP Front ...
#
#                                   card           os
# 0            Memory Card Not Supported  Android v13
# 1      Memory Card (Hybrid), upto 1 TB  Android v12
# 2     Memory Card Supported, upto 1 TB  Android v13
# 3      Memory Card (Hybrid), upto 1 TB  Android v12
# 4            Memory Card Not Supported  Android v13
# ...                                ...          ...
# 1015                       Android v12  No FM Radio
# 1016  Memory Card Supported, upto 1 TB  Android v11
# 1017         Memory Card Not Supported  Android v12
# 1018  Memory Card Supported, upto 1 TB  Android v12
# 1019  Memory Card Supported, upto 1 TB  Android v12
#
# [1020 rows x 12 columns]

# %%
df1
# Out:
#       index                            model  price  rating  \
# 0         2                    OnePlus 11 5G  54999    89.0
# 1         3        OnePlus Nord CE 2 Lite 5G  19989    81.0
# 2         4            Samsung Galaxy A14 5G  16499    75.0
# 3         5             Motorola Moto G62 5G  14999    81.0
# 4         6               Realme 10 Pro Plus  24999    82.0
# ...     ...                              ...    ...     ...
# 1015   1017       Motorola Moto Edge S30 Pro  34990    83.0
# 1016   1018                      Honor X8 5G  14990    75.0
# 1017   1019  POCO X4 GT 5G (8GB RAM + 256GB)  28990    85.0
# 1018   1020             Motorola Moto G91 5G  19990    80.0
# 1019   1021           Samsung Galaxy M52s 5G  24990    74.0
#
#                                                     sim  \
# 0               Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 1                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 2                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 3                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 4                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# ...                                                 ...
# 1015                 Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 1016                 Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 1017  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...
# 1018            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 1019                 Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
#
#                                             processor  \
# 0     Snapdragon 8 Gen2, Octa Core, 3.2 GHz Processor
# 1        Snapdragon 695, Octa Core, 2.2 GHz Processor
# 2           Exynos 1330, Octa Core, 2.4 GHz Processor
# 3       Snapdragon  695, Octa Core, 2.2 GHz Processor
# 4        Dimensity 1080, Octa Core, 2.6 GHz Processor
# ...                                               ...
# 1015    Snapdragon 8 Gen1, Octa Core, 3 GHz Processor
# 1016   Snapdragon  480+, Octa Core, 2.2 GHz Processor
# 1017    Dimensity 8100, Octa Core, 2.85 GHz Processor
# 1018     Snapdragon 695, Octa Core, 2.2 GHz Processor
# 1019                              Octa Core Processor
#
#                             ram                                    battery  \
# 0     12 GB RAM, 256 GB inbuilt   5000 mAh Battery with 100W Fast Charging
# 1      6 GB RAM, 128 GB inbuilt    5000 mAh Battery with 33W Fast Charging
# 2       4 GB RAM, 64 GB inbuilt    5000 mAh Battery with 15W Fast Charging
# 3      6 GB RAM, 128 GB inbuilt        5000 mAh Battery with Fast Charging
# 4      6 GB RAM, 128 GB inbuilt    5000 mAh Battery with 67W Fast Charging
# ...                         ...                                        ...
# 1015   8 GB RAM, 128 GB inbuilt  5000 mAh Battery with 68.2W Fast Charging
# 1016   6 GB RAM, 128 GB inbuilt  5000 mAh Battery with 22.5W Fast Charging
# 1017   8 GB RAM, 256 GB inbuilt    5080 mAh Battery with 67W Fast Charging
# 1018   6 GB RAM, 128 GB inbuilt        5000 mAh Battery with Fast Charging
# 1019   8 GB RAM, 128 GB inbuilt        5000 mAh Battery with Fast Charging
#
#                                                 display  \
# 0     6.7 inches, 1440 x 3216 px, 120 Hz Display wit...
# 1     6.59 inches, 1080 x 2412 px, 120 Hz Display wi...
# 2     6.6 inches, 1080 x 2408 px, 90 Hz Display with...
# 3     6.55 inches, 1080 x 2400 px, 120 Hz Display wi...
# 4     6.7 inches, 1080 x 2412 px, 120 Hz Display wit...
# ...                                                 ...
# 1015  6.67 inches, 1080 x 2460 px, 120 Hz Display wi...
# 1016  6.5 inches, 720 x 1600 px Display with Water D...
# 1017  6.6 inches, 1080 x 2460 px, 144 Hz Display wit...
# 1018  6.8 inches, 1080 x 2400 px Display with Punch ...
# 1019  6.5 inches, 1080 x 2400 px Display with Water ...
#
#                                                  camera  \
# 0     50 MP + 48 MP + 32 MP Triple Rear & 16 MP Fron...
# 1     64 MP + 2 MP + 2 MP Triple Rear & 16 MP Front ...
# 2     50 MP + 2 MP + 2 MP Triple Rear & 13 MP Front ...
# 3     50 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 4     108 MP + 8 MP + 2 MP Triple Rear & 16 MP Front...
# ...                                                 ...
# 1015  64 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 1016  48 MP + 2 MP + Depth Sensor Triple Rear & 8 MP...
# 1017  64 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 1018  108 MP + 8 MP + 2 MP Triple Rear & 32 MP Front...
# 1019  64 MP + 8 MP + 5 MP Triple Rear & 32 MP Front ...
#
#                                   card           os
# 0            Memory Card Not Supported  Android v13
# 1      Memory Card (Hybrid), upto 1 TB  Android v12
# 2     Memory Card Supported, upto 1 TB  Android v13
# 3      Memory Card (Hybrid), upto 1 TB  Android v12
# 4            Memory Card Not Supported  Android v13
# ...                                ...          ...
# 1015                       Android v12  No FM Radio
# 1016  Memory Card Supported, upto 1 TB  Android v11
# 1017         Memory Card Not Supported  Android v12
# 1018  Memory Card Supported, upto 1 TB  Android v12
# 1019  Memory Card Supported, upto 1 TB  Android v12
#
# [1020 rows x 12 columns]

# %%
processor_rows = set((642,647,649,659,667,701,750,759,819,859,883,884,919,927,929,932,1002))
ram_rows = set((441,485,534,553,584,610,613,642,647,649,659,667,701,750,759,819,859,884,919,927,929,932,990,1002))
battery_rows = set((113,151,309,365,378,441,450,553,584,610,613,630,642,647,649,659,667,701,750,756,759,764,819,855,859,884,915,916,927,929,932,990,1002))
display_rows = set((378,441,450,553,584,610,613,630,642,647,649,659,667,701,750,759,764,819,859,884,915,916,927,929,932,990,1002))
camera_rows = set((100,113,151,157,161,238,273,308,309,323,324,365,367,378,394,441,450,484,506,534,553,571,572,575,584,610,613,615,630,642,647,649,659,667,684,687,705,711,723,728,750,756,759,764,792,819,846,854,855,858,883,884,896,915,916,927,929,932,945,956,990,995,1002,1016 ))

# %%
df1[df1['index'].isin(processor_rows | ram_rows | battery_rows | display_rows | camera_rows)]
# Out:
#       index                              model   price  rating  \
# 98      100                     Vivo X Fold 5G  106990     NaN
# 111     113                    Apple iPhone 12   51999    74.0
# 149     151               Apple iPhone 12 Mini   40999    74.0
# 155     157                    Nokia 2780 Flip    4990     NaN
# 159     161                    Oppo Find N2 5G   94990     NaN
# ...     ...                                ...     ...     ...
# 954     956  Vivo X Fold 5G (12GB RAM + 512GB)  118990     NaN
# 988     990                Nokia 5310 Dual Sim    3399     NaN
# 993     995                      Huawei Mate X  169000     NaN
# 1000   1002                    XTouch F40 Flip    1999     NaN
# 1014   1016                      Vivo X Fold 2  119990     NaN
#
#                                                     sim  \
# 98              Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 111             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 149             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 155                             Dual Sim, 3G, 4G, Wi-Fi
# 159             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# ...                                                 ...
# 954             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 988                                            Dual Sim
# 993   Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...
# 1000                                           Dual Sim
# 1014            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
#
#                                              processor  \
# 98       Snapdragon 8 Gen1, Octa Core, 3 GHz Processor
# 111           Bionic A14, Hexa Core, 3.1 GHz Processor
# 149           Bionic A14, Hexa Core, 3.1 GHz Processor
# 155     Snapdragon QM215, Quad Core, 1.3 GHz Processor
# 159   Snapdragon 8+ Gen1, Octa Core, 3.2 GHz Processor
# ...                                                ...
# 954      Snapdragon 8 Gen1, Octa Core, 3 GHz Processor
# 988                            8 MB RAM, 16 MB inbuilt
# 993          Kirin  990, Octa Core, 2.86 GHz Processor
# 1000                                             No 3G
# 1014   Snapdragon 8 Gen2, Octa Core, 3.2 GHz Processor
#
#                             ram  \
# 98    12 GB RAM, 256 GB inbuilt
# 111     4 GB RAM, 64 GB inbuilt
# 149     4 GB RAM, 64 GB inbuilt
# 155    4 GB RAM, 512 MB inbuilt
# 159   12 GB RAM, 256 GB inbuilt
# ...                         ...
# 954   12 GB RAM, 512 GB inbuilt
# 988            1200 mAh Battery
# 993    8 GB RAM, 512 GB inbuilt
# 1000                    No Wifi
# 1014  12 GB RAM, 256 GB inbuilt
#
#                                                 battery  \
# 98              4600 mAh Battery with 66W Fast Charging
# 111   6.1 inches, 1170 x 2532 px Display with Large ...
# 149                  5.4 inches, 1080 x 2340 px Display
# 155                                    1450 mAh Battery
# 159             4520 mAh Battery with 67W Fast Charging
# ...                                                 ...
# 954             4600 mAh Battery with 66W Fast Charging
# 988                    2.4 inches, 240 x 320 px Display
# 993             4500 mAh Battery with 55W Fast Charging
# 1000                           32 MB RAM, 32 MB inbuilt
# 1014            4800 mAh Battery with 66W Fast Charging
#
#                                                 display  \
# 98          8.03 inches, 1916 x 2160 px, 120 Hz Display
# 111        12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 149        12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 155                    2.7 inches, 240 x 320 px Display
# 159   7.1 inches, 1792 x 1920 px, 120 Hz Display wit...
# ...                                                 ...
# 954         8.03 inches, 1916 x 2160 px, 120 Hz Display
# 988                                  0.3 MP Rear Camera
# 993                    8 inches, 2200 x 2480 px Display
# 1000                                    800 mAh Battery
# 1014        8.03 inches, 1916 x 2160 px, 120 Hz Display
#
#                                  camera  \
# 98                     Foldable Display
# 111           Memory Card Not Supported
# 149           Memory Card Not Supported
# 155                        Dual Display
# 159      Foldable Display, Dual Display
# ...                                 ...
# 954                    Foldable Display
# 988   Memory Card Supported, upto 32 GB
# 993                    Foldable Display
# 1000  1.77 inches, 240 x 320 px Display
# 1014                   Foldable Display
#
#                                                    card  \
# 98                 50 MP Quad Rear & 16 MP Front Camera
# 111                                             iOS v14
# 149                                             iOS v14
# 155                                    5 MP Rear Camera
# 159   50 MP + 48 MP + 32 MP Triple Rear & 32 MP + 32...
# ...                                                 ...
# 954                50 MP Quad Rear & 16 MP Front Camera
# 988                                           Bluetooth
# 993                              48 MP Quad Rear Camera
# 1000                                       Dual Display
# 1014  50 MP + 50 MP + 10 MP Triple Rear & 32 MP Fron...
#
#                                      os
# 98                          Android v12
# 111                         No FM Radio
# 149                         No FM Radio
# 155   Memory Card Supported, upto 32 GB
# 159           Memory Card Not Supported
# ...                                 ...
# 954                         Android v12
# 988                             Browser
# 993   Memory Card (Hybrid), upto 256 GB
# 1000                 1.3 MP Rear Camera
# 1014                        Android v12
#
# [68 rows x 12 columns]

# %%
df1[df1['index'].isin(processor_rows & ram_rows & battery_rows & display_rows & camera_rows)]
# Out:
#       index                   model  price  rating  \
# 640     642          Nokia 105 Plus   1299     NaN
# 645     647         Nokia 2760 Flip   5490     NaN
# 647     649       Motorola Moto A10   1339     NaN
# 657     659           Zanco Tiny T1   2799     NaN
# 665     667            itel it2163S    958     NaN
# 748     750            Nokia 400 4G   3290     NaN
# 757     759            Karbonn KU3i    995     NaN
# 817     819            itel Magic X   2239     NaN
# 882     884  Nokia 5710 XpressAudio   4799     NaN
# 925     927           Nokia 3310 4G   3999     NaN
# 927     929      Samsung Guru E1200   1685     NaN
# 930     932        iKall K88 Pro 4G   2099     NaN
# 1000   1002         XTouch F40 Flip   1999     NaN
#
#                                  sim                   processor  \
# 640                         Dual Sim      4 MB RAM, 4 MB inbuilt
# 645          Dual Sim, 3G, 4G, Wi-Fi            1450 mAh Battery
# 647                         Dual Sim      4 MB RAM, 4 MB inbuilt
# 657                       Single Sim    32 MB RAM, 32 MB inbuilt
# 665                         Dual Sim      4 MB RAM, 4 MB inbuilt
# 748       Dual Sim, 4G, VoLTE, Wi-Fi            2000 mAh Battery
# 757                         Dual Sim    52 MB RAM, 32 MB inbuilt
# 817   Dual Sim, 3G, 4G, VoLTE, Wi-Fi                       No 3G
# 882                 Dual Sim, 3G, 4G                     No Wifi
# 925   Dual Sim, 3G, 4G, VoLTE, Wi-Fi  256 MB RAM, 512 MB inbuilt
# 927                       Single Sim                     No Wifi
# 930          Dual Sim, 3G, 4G, VoLTE   48 MB RAM, 128 MB inbuilt
# 1000                        Dual Sim                       No 3G
#
#                                    ram                            battery  \
# 640                    800 mAh Battery  1.77 inches, 128 x 160 px Display
# 645   3.6 inches, 240 x 320 px Display      5 MP Rear & 5 MP Front Camera
# 647                   1750 mAh Battery   1.8 inches, 160 x 128 px Display
# 657                    200 mAh Battery    0.49 inches, 64 x 32 px Display
# 665                   1200 mAh Battery   1.8 inches, 160 x 128 px Display
# 748   2.4 inches, 240 x 320 px Display  0.3 MP Rear & 0.3 MP Front Camera
# 757                   1000 mAh Battery   1.8 inches, 128 x 160 px Display
# 817                               T117          48 MB RAM, 128 MB inbuilt
# 882                        Unisoc T107          48 MB RAM, 128 MB inbuilt
# 925                   1200 mAh Battery   2.4 inches, 240 x 320 px Display
# 927                    800 mAh Battery   1.5 inches, 128 x 128 px Display
# 930                   1800 mAh Battery   2.4 inches, 240 x 360 px Display
# 1000                           No Wifi           32 MB RAM, 32 MB inbuilt
#
#                                 display                              camera  \
# 640                      No Rear Camera   Memory Card Supported, upto 32 GB
# 645   Memory Card Supported, upto 32 GB                          Kaios v3.0
# 647                      No Rear Camera   Memory Card Supported, upto 32 GB
# 657                      No Rear Camera                         No FM Radio
# 665                      No Rear Camera   Memory Card Supported, upto 32 GB
# 748   Memory Card Supported, upto 64 GB                           Bluetooth
# 757                      No Rear Camera   Memory Card Supported, upto 16 GB
# 817                    1200 mAh Battery    2.4 inches, 240 x 320 px Display
# 882                    1450 mAh Battery    2.4 inches, 240 x 320 px Display
# 925                    2 MP Rear Camera   Memory Card Supported, upto 32 GB
# 927                      No Rear Camera                         No FM Radio
# 930                  0.3 MP Rear Camera  Memory Card Supported, upto 128 GB
# 1000                    800 mAh Battery   1.77 inches, 240 x 320 px Display
#
#                     card                                 os
# 640            Bluetooth                                NaN
# 645            Bluetooth                                NaN
# 647                  NaN                                NaN
# 657            Bluetooth                                NaN
# 665            Bluetooth                                NaN
# 748              Browser                                NaN
# 757            Bluetooth                                NaN
# 817   1.3 MP Rear Camera  Memory Card Supported, upto 64 GB
# 882   0.3 MP Rear Camera  Memory Card Supported, upto 32 GB
# 925            Bluetooth                            Browser
# 927                  NaN                                NaN
# 930            Bluetooth                            Browser
# 1000        Dual Display                 1.3 MP Rear Camera

# %%
df1[df1['index'].isin(processor_rows & ram_rows & battery_rows & display_rows & camera_rows)]['price'].mean()
# Out:
# 2537.6923076923076

# %%
df1[df1['price'] >= 3400]
# Out:
#       index                            model  price  rating  \
# 0         2                    OnePlus 11 5G  54999    89.0
# 1         3        OnePlus Nord CE 2 Lite 5G  19989    81.0
# 2         4            Samsung Galaxy A14 5G  16499    75.0
# 3         5             Motorola Moto G62 5G  14999    81.0
# 4         6               Realme 10 Pro Plus  24999    82.0
# ...     ...                              ...    ...     ...
# 1015   1017       Motorola Moto Edge S30 Pro  34990    83.0
# 1016   1018                      Honor X8 5G  14990    75.0
# 1017   1019  POCO X4 GT 5G (8GB RAM + 256GB)  28990    85.0
# 1018   1020             Motorola Moto G91 5G  19990    80.0
# 1019   1021           Samsung Galaxy M52s 5G  24990    74.0
#
#                                                     sim  \
# 0               Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 1                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 2                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 3                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 4                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# ...                                                 ...
# 1015                 Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 1016                 Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 1017  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...
# 1018            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 1019                 Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
#
#                                             processor  \
# 0     Snapdragon 8 Gen2, Octa Core, 3.2 GHz Processor
# 1        Snapdragon 695, Octa Core, 2.2 GHz Processor
# 2           Exynos 1330, Octa Core, 2.4 GHz Processor
# 3       Snapdragon  695, Octa Core, 2.2 GHz Processor
# 4        Dimensity 1080, Octa Core, 2.6 GHz Processor
# ...                                               ...
# 1015    Snapdragon 8 Gen1, Octa Core, 3 GHz Processor
# 1016   Snapdragon  480+, Octa Core, 2.2 GHz Processor
# 1017    Dimensity 8100, Octa Core, 2.85 GHz Processor
# 1018     Snapdragon 695, Octa Core, 2.2 GHz Processor
# 1019                              Octa Core Processor
#
#                             ram                                    battery  \
# 0     12 GB RAM, 256 GB inbuilt   5000 mAh Battery with 100W Fast Charging
# 1      6 GB RAM, 128 GB inbuilt    5000 mAh Battery with 33W Fast Charging
# 2       4 GB RAM, 64 GB inbuilt    5000 mAh Battery with 15W Fast Charging
# 3      6 GB RAM, 128 GB inbuilt        5000 mAh Battery with Fast Charging
# 4      6 GB RAM, 128 GB inbuilt    5000 mAh Battery with 67W Fast Charging
# ...                         ...                                        ...
# 1015   8 GB RAM, 128 GB inbuilt  5000 mAh Battery with 68.2W Fast Charging
# 1016   6 GB RAM, 128 GB inbuilt  5000 mAh Battery with 22.5W Fast Charging
# 1017   8 GB RAM, 256 GB inbuilt    5080 mAh Battery with 67W Fast Charging
# 1018   6 GB RAM, 128 GB inbuilt        5000 mAh Battery with Fast Charging
# 1019   8 GB RAM, 128 GB inbuilt        5000 mAh Battery with Fast Charging
#
#                                                 display  \
# 0     6.7 inches, 1440 x 3216 px, 120 Hz Display wit...
# 1     6.59 inches, 1080 x 2412 px, 120 Hz Display wi...
# 2     6.6 inches, 1080 x 2408 px, 90 Hz Display with...
# 3     6.55 inches, 1080 x 2400 px, 120 Hz Display wi...
# 4     6.7 inches, 1080 x 2412 px, 120 Hz Display wit...
# ...                                                 ...
# 1015  6.67 inches, 1080 x 2460 px, 120 Hz Display wi...
# 1016  6.5 inches, 720 x 1600 px Display with Water D...
# 1017  6.6 inches, 1080 x 2460 px, 144 Hz Display wit...
# 1018  6.8 inches, 1080 x 2400 px Display with Punch ...
# 1019  6.5 inches, 1080 x 2400 px Display with Water ...
#
#                                                  camera  \
# 0     50 MP + 48 MP + 32 MP Triple Rear & 16 MP Fron...
# 1     64 MP + 2 MP + 2 MP Triple Rear & 16 MP Front ...
# 2     50 MP + 2 MP + 2 MP Triple Rear & 13 MP Front ...
# 3     50 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 4     108 MP + 8 MP + 2 MP Triple Rear & 16 MP Front...
# ...                                                 ...
# 1015  64 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 1016  48 MP + 2 MP + Depth Sensor Triple Rear & 8 MP...
# 1017  64 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 1018  108 MP + 8 MP + 2 MP Triple Rear & 32 MP Front...
# 1019  64 MP + 8 MP + 5 MP Triple Rear & 32 MP Front ...
#
#                                   card           os
# 0            Memory Card Not Supported  Android v13
# 1      Memory Card (Hybrid), upto 1 TB  Android v12
# 2     Memory Card Supported, upto 1 TB  Android v13
# 3      Memory Card (Hybrid), upto 1 TB  Android v12
# 4            Memory Card Not Supported  Android v13
# ...                                ...          ...
# 1015                       Android v12  No FM Radio
# 1016  Memory Card Supported, upto 1 TB  Android v11
# 1017         Memory Card Not Supported  Android v12
# 1018  Memory Card Supported, upto 1 TB  Android v12
# 1019  Memory Card Supported, upto 1 TB  Android v12
#
# [991 rows x 12 columns]

# %%
df1[df1['index'].isin(processor_rows)]
# Out:
#       index                   model  price  rating  \
# 640     642          Nokia 105 Plus   1299     NaN
# 645     647         Nokia 2760 Flip   5490     NaN
# 647     649       Motorola Moto A10   1339     NaN
# 657     659           Zanco Tiny T1   2799     NaN
# 665     667            itel it2163S    958     NaN
# 699     701   Samsung Guru GT-E1215   1850     NaN
# 748     750            Nokia 400 4G   3290     NaN
# 757     759            Karbonn KU3i    995     NaN
# 817     819            itel Magic X   2239     NaN
# 857     859             LG Folder 2  11999     NaN
# 881     883        Nokia 110 (2022)   1599     NaN
# 882     884  Nokia 5710 XpressAudio   4799     NaN
# 917     919        Nokia 150 (2020)   2499     NaN
# 925     927           Nokia 3310 4G   3999     NaN
# 927     929      Samsung Guru E1200   1685     NaN
# 930     932        iKall K88 Pro 4G   2099     NaN
# 1000   1002         XTouch F40 Flip   1999     NaN
#
#                                  sim                   processor  \
# 640                         Dual Sim      4 MB RAM, 4 MB inbuilt
# 645          Dual Sim, 3G, 4G, Wi-Fi            1450 mAh Battery
# 647                         Dual Sim      4 MB RAM, 4 MB inbuilt
# 657                       Single Sim    32 MB RAM, 32 MB inbuilt
# 665                         Dual Sim      4 MB RAM, 4 MB inbuilt
# 699                       Single Sim             800 mAh Battery
# 748       Dual Sim, 4G, VoLTE, Wi-Fi            2000 mAh Battery
# 757                         Dual Sim    52 MB RAM, 32 MB inbuilt
# 817   Dual Sim, 3G, 4G, VoLTE, Wi-Fi                       No 3G
# 857        Single Sim, 3G, 4G, Wi-Fi      1 GB RAM, 8 GB inbuilt
# 881                         Dual Sim                     No Wifi
# 882                 Dual Sim, 3G, 4G                     No Wifi
# 917                         Dual Sim                     No Wifi
# 925   Dual Sim, 3G, 4G, VoLTE, Wi-Fi  256 MB RAM, 512 MB inbuilt
# 927                       Single Sim                     No Wifi
# 930          Dual Sim, 3G, 4G, VoLTE   48 MB RAM, 128 MB inbuilt
# 1000                        Dual Sim                       No 3G
#
#                                    ram                            battery  \
# 640                    800 mAh Battery  1.77 inches, 128 x 160 px Display
# 645   3.6 inches, 240 x 320 px Display      5 MP Rear & 5 MP Front Camera
# 647                   1750 mAh Battery   1.8 inches, 160 x 128 px Display
# 657                    200 mAh Battery    0.49 inches, 64 x 32 px Display
# 665                   1200 mAh Battery   1.8 inches, 160 x 128 px Display
# 699   1.5 inches, 120 x 120 px Display                     No Rear Camera
# 748   2.4 inches, 240 x 320 px Display  0.3 MP Rear & 0.3 MP Front Camera
# 757                   1000 mAh Battery   1.8 inches, 128 x 160 px Display
# 817                               T117          48 MB RAM, 128 MB inbuilt
# 857                   1470 mAh Battery   2.8 inches, 240 x 320 px Display
# 881             4 MB RAM, 4 MB inbuilt                   1000 mAh Battery
# 882                        Unisoc T107          48 MB RAM, 128 MB inbuilt
# 917                       4 MB inbuilt                   1020 mAh Battery
# 925                   1200 mAh Battery   2.4 inches, 240 x 320 px Display
# 927                    800 mAh Battery   1.5 inches, 128 x 128 px Display
# 930                   1800 mAh Battery   2.4 inches, 240 x 360 px Display
# 1000                           No Wifi           32 MB RAM, 32 MB inbuilt
#
#                                 display                              camera  \
# 640                      No Rear Camera   Memory Card Supported, upto 32 GB
# 645   Memory Card Supported, upto 32 GB                          Kaios v3.0
# 647                      No Rear Camera   Memory Card Supported, upto 32 GB
# 657                      No Rear Camera                         No FM Radio
# 665                      No Rear Camera   Memory Card Supported, upto 32 GB
# 699                         No FM Radio                                 NaN
# 748   Memory Card Supported, upto 64 GB                           Bluetooth
# 757                      No Rear Camera   Memory Card Supported, upto 16 GB
# 817                    1200 mAh Battery    2.4 inches, 240 x 320 px Display
# 857                    2 MP Rear Camera               Memory Card Supported
# 881   1.77 inches, 120 x 160 px Display   Memory Card Supported, upto 32 GB
# 882                    1450 mAh Battery    2.4 inches, 240 x 320 px Display
# 917    2.4 inches, 240 x 320 px Display                  0.3 MP Rear Camera
# 925                    2 MP Rear Camera   Memory Card Supported, upto 32 GB
# 927                      No Rear Camera                         No FM Radio
# 930                  0.3 MP Rear Camera  Memory Card Supported, upto 128 GB
# 1000                    800 mAh Battery   1.77 inches, 240 x 320 px Display
#
#                                    card                                 os
# 640                           Bluetooth                                NaN
# 645                           Bluetooth                                NaN
# 647                                 NaN                                NaN
# 657                           Bluetooth                                NaN
# 665                           Bluetooth                                NaN
# 699                                 NaN                                NaN
# 748                             Browser                                NaN
# 757                           Bluetooth                                NaN
# 817                  1.3 MP Rear Camera  Memory Card Supported, upto 64 GB
# 857                           Bluetooth                                NaN
# 881                                 NaN                                NaN
# 882                  0.3 MP Rear Camera  Memory Card Supported, upto 32 GB
# 917   Memory Card Supported, upto 32 GB                          Bluetooth
# 925                           Bluetooth                            Browser
# 927                                 NaN                                NaN
# 930                           Bluetooth                            Browser
# 1000                       Dual Display                 1.3 MP Rear Camera

# %%
df1[df1['index'].isin(ram_rows)]
# Out:
#       index                             model   price  rating  \
# 439     441            Apple iPhone SE 3 2022   43900     NaN
# 483     485  Huawei Mate 50 RS Porsche Design  239999    81.0
# 532     534     Samsung Guru Music 2 Dual Sim    1949     NaN
# 551     553                   itel Magic 2 4G    2399     NaN
# 582     584                     Nokia 8210 4G    3749     NaN
# 608     610                 Namotel Achhe Din      99     NaN
# 611     613                   Eunity U1 5605N     699     NaN
# 640     642                    Nokia 105 Plus    1299     NaN
# 645     647                   Nokia 2760 Flip    5490     NaN
# 647     649                 Motorola Moto A10    1339     NaN
# 657     659                     Zanco Tiny T1    2799     NaN
# 665     667                      itel it2163S     958     NaN
# 699     701             Samsung Guru GT-E1215    1850     NaN
# 748     750                      Nokia 400 4G    3290     NaN
# 757     759                      Karbonn KU3i     995     NaN
# 817     819                      itel Magic X    2239     NaN
# 857     859                       LG Folder 2   11999     NaN
# 882     884            Nokia 5710 XpressAudio    4799     NaN
# 917     919                  Nokia 150 (2020)    2499     NaN
# 925     927                     Nokia 3310 4G    3999     NaN
# 927     929                Samsung Guru E1200    1685     NaN
# 930     932                  iKall K88 Pro 4G    2099     NaN
# 988     990               Nokia 5310 Dual Sim    3399     NaN
# 1000   1002                   XTouch F40 Flip    1999     NaN
#
#                                                   sim  \
# 439           Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 483   Dual Sim, 3G, 4G, VoLTE, Wi-Fi, NFC, IR Blaster
# 532                                          Dual Sim
# 551                    Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 582                                  Dual Sim, 3G, 4G
# 608                               Dual Sim, 3G, Wi-Fi
# 611                                          Dual Sim
# 640                                          Dual Sim
# 645                           Dual Sim, 3G, 4G, Wi-Fi
# 647                                          Dual Sim
# 657                                        Single Sim
# 665                                          Dual Sim
# 699                                        Single Sim
# 748                        Dual Sim, 4G, VoLTE, Wi-Fi
# 757                                          Dual Sim
# 817                    Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 857                         Single Sim, 3G, 4G, Wi-Fi
# 882                                  Dual Sim, 3G, 4G
# 917                                          Dual Sim
# 925                    Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 927                                        Single Sim
# 930                           Dual Sim, 3G, 4G, VoLTE
# 988                                          Dual Sim
# 1000                                         Dual Sim
#
#                                              processor  \
# 439         Bionic  A15, Hexa Core, 3.22 GHz Processor
# 483   Snapdragon 8+ Gen1, Octa Core, 3.2 GHz Processor
# 532                                            No Wifi
# 551                                              No 3G
# 582                                            No Wifi
# 608                             1 GB RAM, 4 GB inbuilt
# 611                                              No 3G
# 640                             4 MB RAM, 4 MB inbuilt
# 645                                   1450 mAh Battery
# 647                             4 MB RAM, 4 MB inbuilt
# 657                           32 MB RAM, 32 MB inbuilt
# 665                             4 MB RAM, 4 MB inbuilt
# 699                                    800 mAh Battery
# 748                                   2000 mAh Battery
# 757                           52 MB RAM, 32 MB inbuilt
# 817                                              No 3G
# 857                             1 GB RAM, 8 GB inbuilt
# 882                                            No Wifi
# 917                                            No Wifi
# 925                         256 MB RAM, 512 MB inbuilt
# 927                                            No Wifi
# 930                          48 MB RAM, 128 MB inbuilt
# 988                            8 MB RAM, 16 MB inbuilt
# 1000                                             No 3G
#
#                                    ram  \
# 439                      64 GB inbuilt
# 483                     512 GB inbuilt
# 532     Single Core, 208 MHz Processor
# 551                               T117
# 582                        Unisoc T107
# 608                   1325 mAh Battery
# 611       Dual Core, 500 MHz Processor
# 640                    800 mAh Battery
# 645   3.6 inches, 240 x 320 px Display
# 647                   1750 mAh Battery
# 657                    200 mAh Battery
# 665                   1200 mAh Battery
# 699   1.5 inches, 120 x 120 px Display
# 748   2.4 inches, 240 x 320 px Display
# 757                   1000 mAh Battery
# 817                               T117
# 857                   1470 mAh Battery
# 882                        Unisoc T107
# 917                       4 MB inbuilt
# 925                   1200 mAh Battery
# 927                    800 mAh Battery
# 930                   1800 mAh Battery
# 988                   1200 mAh Battery
# 1000                           No Wifi
#
#                                       battery  \
# 439         4.7 inches, 750 x 1334 px Display
# 483   4700 mAh Battery with 66W Fast Charging
# 532                           800 mAh Battery
# 551                 64 MB RAM, 128 MB inbuilt
# 582                 48 MB RAM, 128 MB inbuilt
# 608           4 inches, 720 x 1280 px Display
# 611                  32 MB RAM, 32 MB inbuilt
# 640         1.77 inches, 128 x 160 px Display
# 645             5 MP Rear & 5 MP Front Camera
# 647          1.8 inches, 160 x 128 px Display
# 657           0.49 inches, 64 x 32 px Display
# 665          1.8 inches, 160 x 128 px Display
# 699                            No Rear Camera
# 748         0.3 MP Rear & 0.3 MP Front Camera
# 757          1.8 inches, 128 x 160 px Display
# 817                 48 MB RAM, 128 MB inbuilt
# 857          2.8 inches, 240 x 320 px Display
# 882                 48 MB RAM, 128 MB inbuilt
# 917                          1020 mAh Battery
# 925          2.4 inches, 240 x 320 px Display
# 927          1.5 inches, 128 x 128 px Display
# 930          2.4 inches, 240 x 360 px Display
# 988          2.4 inches, 240 x 320 px Display
# 1000                 32 MB RAM, 32 MB inbuilt
#
#                                           display  \
# 439                12 MP Rear & 7 MP Front Camera
# 483   6.74 inches, 1212 x 2616 px, 120 Hz Display
# 532                2 inches, 128 x 160 px Display
# 551                              1900 mAh Battery
# 582                              1450 mAh Battery
# 608               2 MP Rear & 0.3 MP Front Camera
# 611                              3000 mAh Battery
# 640                                No Rear Camera
# 645             Memory Card Supported, upto 32 GB
# 647                                No Rear Camera
# 657                                No Rear Camera
# 665                                No Rear Camera
# 699                                   No FM Radio
# 748             Memory Card Supported, upto 64 GB
# 757                                No Rear Camera
# 817                              1200 mAh Battery
# 857                              2 MP Rear Camera
# 882                              1450 mAh Battery
# 917              2.4 inches, 240 x 320 px Display
# 925                              2 MP Rear Camera
# 927                                No Rear Camera
# 930                            0.3 MP Rear Camera
# 988                            0.3 MP Rear Camera
# 1000                              800 mAh Battery
#
#                                                  camera  \
# 439                           Memory Card Not Supported
# 483   50 MP + 48 MP + 13 MP Triple Rear & 13 MP Fron...
# 532                                      No Rear Camera
# 551                    2.4 inches, 240 x 320 px Display
# 582                    2.8 inches, 240 x 320 px Display
# 608                             Android v5.0 (Lollipop)
# 611                    1.8 inches, 128 x 160 px Display
# 640                   Memory Card Supported, upto 32 GB
# 645                                          Kaios v3.0
# 647                   Memory Card Supported, upto 32 GB
# 657                                         No FM Radio
# 665                   Memory Card Supported, upto 32 GB
# 699                                                 NaN
# 748                                           Bluetooth
# 757                   Memory Card Supported, upto 16 GB
# 817                    2.4 inches, 240 x 320 px Display
# 857                               Memory Card Supported
# 882                    2.4 inches, 240 x 320 px Display
# 917                                  0.3 MP Rear Camera
# 925                   Memory Card Supported, upto 32 GB
# 927                                         No FM Radio
# 930                  Memory Card Supported, upto 128 GB
# 988                   Memory Card Supported, upto 32 GB
# 1000                  1.77 inches, 240 x 320 px Display
#
#                                    card                                 os
# 439                             iOS v15                        No FM Radio
# 483   Memory Card (Hybrid), upto 256 GB                   Hongmeng OS v3.0
# 532   Memory Card Supported, upto 16 GB                                NaN
# 551                  1.3 MP Rear Camera  Memory Card Supported, upto 64 GB
# 582                  0.3 MP Rear Camera  Memory Card Supported, upto 32 GB
# 608                           Bluetooth                                NaN
# 611                  0.3 MP Rear Camera  Memory Card Supported, upto 16 GB
# 640                           Bluetooth                                NaN
# 645                           Bluetooth                                NaN
# 647                                 NaN                                NaN
# 657                           Bluetooth                                NaN
# 665                           Bluetooth                                NaN
# 699                                 NaN                                NaN
# 748                             Browser                                NaN
# 757                           Bluetooth                                NaN
# 817                  1.3 MP Rear Camera  Memory Card Supported, upto 64 GB
# 857                           Bluetooth                                NaN
# 882                  0.3 MP Rear Camera  Memory Card Supported, upto 32 GB
# 917   Memory Card Supported, upto 32 GB                          Bluetooth
# 925                           Bluetooth                            Browser
# 927                                 NaN                                NaN
# 930                           Bluetooth                            Browser
# 988                           Bluetooth                            Browser
# 1000                       Dual Display                 1.3 MP Rear Camera

# %%
df1.drop(582,inplace = True)

# %%
df1[df1['index'].isin(battery_rows)]
# Out:
#       index                         model   price  rating  \
# 111     113               Apple iPhone 12   51999    74.0
# 149     151          Apple iPhone 12 Mini   40999    74.0
# 307     309       Apple iPhone 12 (128GB)   55999    75.0
# 363     365  Apple iPhone 12 Mini (128GB)   45999    75.0
# 376     378               Nokia 2660 Flip    4649     NaN
# 439     441        Apple iPhone SE 3 2022   43900     NaN
# 448     450           Apple iPhone 15 Pro  130990    75.0
# 551     553               itel Magic 2 4G    2399     NaN
# 608     610             Namotel Achhe Din      99     NaN
# 611     613               Eunity U1 5605N     699     NaN
# 628     630   Apple iPhone 12 Pro (512GB)  139900    80.0
# 640     642                Nokia 105 Plus    1299     NaN
# 645     647               Nokia 2760 Flip    5490     NaN
# 647     649             Motorola Moto A10    1339     NaN
# 657     659                 Zanco Tiny T1    2799     NaN
# 665     667                  itel it2163S     958     NaN
# 699     701         Samsung Guru GT-E1215    1850     NaN
# 748     750                  Nokia 400 4G    3290     NaN
# 754     756    Apple iPod Touch (7th Gen)   18900     NaN
# 757     759                  Karbonn KU3i     995     NaN
# 762     764             Apple iPhone SE 4   49990    60.0
# 817     819                  itel Magic X    2239     NaN
# 853     855   Apple iPhone 12 Pro (256GB)  119900    80.0
# 857     859                   LG Folder 2   11999     NaN
# 882     884        Nokia 5710 XpressAudio    4799     NaN
# 913     915  Apple iPhone 12 Mini (256GB)   55999    75.0
# 914     916       Apple iPhone 12 (256GB)   67999    76.0
# 925     927                 Nokia 3310 4G    3999     NaN
# 927     929            Samsung Guru E1200    1685     NaN
# 930     932              iKall K88 Pro 4G    2099     NaN
# 988     990           Nokia 5310 Dual Sim    3399     NaN
# 1000   1002               XTouch F40 Flip    1999     NaN
#
#                                           sim  \
# 111   Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 149   Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 307   Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 363   Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 376                          Dual Sim, 3G, 4G
# 439   Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 448   Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 551            Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 608                       Dual Sim, 3G, Wi-Fi
# 611                                  Dual Sim
# 628   Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 640                                  Dual Sim
# 645                   Dual Sim, 3G, 4G, Wi-Fi
# 647                                  Dual Sim
# 657                                Single Sim
# 665                                  Dual Sim
# 699                                Single Sim
# 748                Dual Sim, 4G, VoLTE, Wi-Fi
# 754                                     Wi-Fi
# 757                                  Dual Sim
# 762   Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 817            Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 853   Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 857                 Single Sim, 3G, 4G, Wi-Fi
# 882                          Dual Sim, 3G, 4G
# 913   Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 914   Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 925            Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 927                                Single Sim
# 930                   Dual Sim, 3G, 4G, VoLTE
# 988                                  Dual Sim
# 1000                                 Dual Sim
#
#                                        processor  \
# 111     Bionic A14, Hexa Core, 3.1 GHz Processor
# 149     Bionic A14, Hexa Core, 3.1 GHz Processor
# 307     Bionic A14, Hexa Core, 3.1 GHz Processor
# 363     Bionic A14, Hexa Core, 3.1 GHz Processor
# 376                                      No Wifi
# 439   Bionic  A15, Hexa Core, 3.22 GHz Processor
# 448                                  Bionic  A16
# 551                                        No 3G
# 608                       1 GB RAM, 4 GB inbuilt
# 611                                        No 3G
# 628     Bionic A14, Hexa Core, 3.1 GHz Processor
# 640                       4 MB RAM, 4 MB inbuilt
# 645                             1450 mAh Battery
# 647                       4 MB RAM, 4 MB inbuilt
# 657                     32 MB RAM, 32 MB inbuilt
# 665                       4 MB RAM, 4 MB inbuilt
# 699                              800 mAh Battery
# 748                             2000 mAh Battery
# 754                                32 GB inbuilt
# 757                     52 MB RAM, 32 MB inbuilt
# 762   Bionic  A15, Hexa Core, 3.22 GHz Processor
# 817                                        No 3G
# 853     Bionic A14, Hexa Core, 3.1 GHz Processor
# 857                       1 GB RAM, 8 GB inbuilt
# 882                                      No Wifi
# 913     Bionic A14, Hexa Core, 3.1 GHz Processor
# 914     Bionic A14, Hexa Core, 3.1 GHz Processor
# 925                   256 MB RAM, 512 MB inbuilt
# 927                                      No Wifi
# 930                    48 MB RAM, 128 MB inbuilt
# 988                      8 MB RAM, 16 MB inbuilt
# 1000                                       No 3G
#
#                                    ram  \
# 111            4 GB RAM, 64 GB inbuilt
# 149            4 GB RAM, 64 GB inbuilt
# 307           4 GB RAM, 128 GB inbuilt
# 363           4 GB RAM, 128 GB inbuilt
# 376                        Unisoc T107
# 439                      64 GB inbuilt
# 448           8 GB RAM, 128 GB inbuilt
# 551                               T117
# 608                   1325 mAh Battery
# 611       Dual Core, 500 MHz Processor
# 628           6 GB RAM, 512 GB inbuilt
# 640                    800 mAh Battery
# 645   3.6 inches, 240 x 320 px Display
# 647                   1750 mAh Battery
# 657                    200 mAh Battery
# 665                   1200 mAh Battery
# 699   1.5 inches, 120 x 120 px Display
# 748   2.4 inches, 240 x 320 px Display
# 754    4 inches, 640 x 1136 px Display
# 757                   1000 mAh Battery
# 762                      64 GB inbuilt
# 817                               T117
# 853           6 GB RAM, 256 GB inbuilt
# 857                   1470 mAh Battery
# 882                        Unisoc T107
# 913           4 GB RAM, 256 GB inbuilt
# 914           4 GB RAM, 256 GB inbuilt
# 925                   1200 mAh Battery
# 927                    800 mAh Battery
# 930                   1800 mAh Battery
# 988                   1200 mAh Battery
# 1000                           No Wifi
#
#                                                 battery  \
# 111   6.1 inches, 1170 x 2532 px Display with Large ...
# 149                  5.4 inches, 1080 x 2340 px Display
# 307   6.1 inches, 1170 x 2532 px Display with Large ...
# 363                  5.4 inches, 1080 x 2340 px Display
# 376                           48 MB RAM, 128 MB inbuilt
# 439                   4.7 inches, 750 x 1334 px Display
# 448   6.06 inches, 1170 x 2532 px, 120 Hz Display wi...
# 551                           64 MB RAM, 128 MB inbuilt
# 608                     4 inches, 720 x 1280 px Display
# 611                            32 MB RAM, 32 MB inbuilt
# 628   6.1 inches, 1170 x 2532 px Display with Large ...
# 640                   1.77 inches, 128 x 160 px Display
# 645                       5 MP Rear & 5 MP Front Camera
# 647                    1.8 inches, 160 x 128 px Display
# 657                     0.49 inches, 64 x 32 px Display
# 665                    1.8 inches, 160 x 128 px Display
# 699                                      No Rear Camera
# 748                   0.3 MP Rear & 0.3 MP Front Camera
# 754                     8 MP Rear & 1.2 MP Front Camera
# 757                    1.8 inches, 128 x 160 px Display
# 762                   6.1 inches, 750 x 1580 px Display
# 817                           48 MB RAM, 128 MB inbuilt
# 853   6.1 inches, 1170 x 2532 px Display with Large ...
# 857                    2.8 inches, 240 x 320 px Display
# 882                           48 MB RAM, 128 MB inbuilt
# 913                  5.4 inches, 1080 x 2340 px Display
# 914   6.1 inches, 1170 x 2532 px Display with Large ...
# 925                    2.4 inches, 240 x 320 px Display
# 927                    1.5 inches, 128 x 128 px Display
# 930                    2.4 inches, 240 x 360 px Display
# 988                    2.4 inches, 240 x 320 px Display
# 1000                           32 MB RAM, 32 MB inbuilt
#
#                                                 display  \
# 111        12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 149        12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 307        12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 363        12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 376                                    1450 mAh Battery
# 439                      12 MP Rear & 7 MP Front Camera
# 448   50 MP + 12 MP + 12 MP Triple Rear & 12 MP Fron...
# 551                                    1900 mAh Battery
# 608                     2 MP Rear & 0.3 MP Front Camera
# 611                                    3000 mAh Battery
# 628   12 MP + 12 MP + 12 MP Triple Rear & 12 MP Fron...
# 640                                      No Rear Camera
# 645                   Memory Card Supported, upto 32 GB
# 647                                      No Rear Camera
# 657                                      No Rear Camera
# 665                                      No Rear Camera
# 699                                         No FM Radio
# 748                   Memory Card Supported, upto 64 GB
# 754                                             iOS v12
# 757                                      No Rear Camera
# 762                   12 MP Rear & 10.8 MP Front Camera
# 817                                    1200 mAh Battery
# 853   12 MP + 12 MP + 12 MP Triple Rear & 12 MP Fron...
# 857                                    2 MP Rear Camera
# 882                                    1450 mAh Battery
# 913        12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 914        12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 925                                    2 MP Rear Camera
# 927                                      No Rear Camera
# 930                                  0.3 MP Rear Camera
# 988                                  0.3 MP Rear Camera
# 1000                                    800 mAh Battery
#
#                                   camera                card  \
# 111            Memory Card Not Supported             iOS v14
# 149            Memory Card Not Supported             iOS v14
# 307            Memory Card Not Supported             iOS v14
# 363            Memory Card Not Supported             iOS v14
# 376     2.8 inches, 240 x 320 px Display        Dual Display
# 439            Memory Card Not Supported             iOS v15
# 448            Memory Card Not Supported             iOS v15
# 551     2.4 inches, 240 x 320 px Display  1.3 MP Rear Camera
# 608              Android v5.0 (Lollipop)           Bluetooth
# 611     1.8 inches, 128 x 160 px Display  0.3 MP Rear Camera
# 628            Memory Card Not Supported           iOS v14.0
# 640    Memory Card Supported, upto 32 GB           Bluetooth
# 645                           Kaios v3.0           Bluetooth
# 647    Memory Card Supported, upto 32 GB                 NaN
# 657                          No FM Radio           Bluetooth
# 665    Memory Card Supported, upto 32 GB           Bluetooth
# 699                                  NaN                 NaN
# 748                            Bluetooth             Browser
# 754                          No FM Radio           Bluetooth
# 757    Memory Card Supported, upto 16 GB           Bluetooth
# 762            Memory Card Not Supported             iOS v16
# 817     2.4 inches, 240 x 320 px Display  1.3 MP Rear Camera
# 853            Memory Card Not Supported           iOS v14.0
# 857                Memory Card Supported           Bluetooth
# 882     2.4 inches, 240 x 320 px Display  0.3 MP Rear Camera
# 913            Memory Card Not Supported             iOS v14
# 914            Memory Card Not Supported             iOS v14
# 925    Memory Card Supported, upto 32 GB           Bluetooth
# 927                          No FM Radio                 NaN
# 930   Memory Card Supported, upto 128 GB           Bluetooth
# 988    Memory Card Supported, upto 32 GB           Bluetooth
# 1000   1.77 inches, 240 x 320 px Display        Dual Display
#
#                                      os
# 111                         No FM Radio
# 149                         No FM Radio
# 307                         No FM Radio
# 363                         No FM Radio
# 376                  0.3 MP Rear Camera
# 439                         No FM Radio
# 448                         No FM Radio
# 551   Memory Card Supported, upto 64 GB
# 608                                 NaN
# 611   Memory Card Supported, upto 16 GB
# 628                         No FM Radio
# 640                                 NaN
# 645                                 NaN
# 647                                 NaN
# 657                                 NaN
# 665                                 NaN
# 699                                 NaN
# 748                                 NaN
# 754                             Browser
# 757                                 NaN
# 762                         No FM Radio
# 817   Memory Card Supported, upto 64 GB
# 853                         No FM Radio
# 857                                 NaN
# 882   Memory Card Supported, upto 32 GB
# 913                         No FM Radio
# 914                         No FM Radio
# 925                             Browser
# 927                                 NaN
# 930                             Browser
# 988                             Browser
# 1000                 1.3 MP Rear Camera

# %%
df1.drop([376,754], inplace=True)

# %%
temp_df = df1[df1['index'].isin(battery_rows)]

# %%
x = temp_df.iloc[:,7:].shift(1, axis = 1).values
x
# Out:
# array([[None,
#         '6.1 inches, 1170\u2009x\u20092532\u2009px Display with Large Notch',
#         '12\u2009MP + 12\u2009MP Dual Rear & 12\u2009MP Front Camera',
#         'Memory Card Not Supported', 'iOS v14'],
#        [None, '5.4 inches, 1080\u2009x\u20092340\u2009px Display',
#         '12\u2009MP + 12\u2009MP Dual Rear & 12\u2009MP Front Camera',
#         'Memory Card Not Supported', 'iOS v14'],
#        [None,
#         '6.1 inches, 1170\u2009x\u20092532\u2009px Display with Large Notch',
#         '12\u2009MP + 12\u2009MP Dual Rear & 12\u2009MP Front Camera',
#         'Memory Card Not Supported', 'iOS v14'],
#        [None, '5.4 inches, 1080\u2009x\u20092340\u2009px Display',
#         '12\u2009MP + 12\u2009MP Dual Rear & 12\u2009MP Front Camera',
#         'Memory Card Not Supported', 'iOS v14'],
#        [None, '4.7 inches, 750\u2009x\u20091334\u2009px Display',
#         '12\u2009MP Rear & 7\u2009MP Front Camera',
#         'Memory Card Not Supported', 'iOS v15'],
#        [None,
#         '6.06 inches, 1170\u2009x\u20092532\u2009px, 120 Hz Display with Punch Hole',
#         '50\u2009MP + 12\u2009MP + 12\u2009MP Triple Rear & 12\u2009MP Front Camera',
#         'Memory Card Not Supported', 'iOS v15'],
#        [None, '64\u2009MB RAM, 128\u2009MB inbuilt',
#         '1900\u2009mAh Battery',
#         '2.4 inches, 240\u2009x\u2009320\u2009px Display',
#         '1.3\u2009MP Rear Camera'],
#        [None, '4 inches, 720\u2009x\u20091280\u2009px Display',
#         '2\u2009MP Rear & 0.3\u2009MP Front Camera',
#         'Android v5.0 (Lollipop)', 'Bluetooth'],
#        [None, '32\u2009MB RAM, 32\u2009MB inbuilt',
#         '3000\u2009mAh Battery',
#         '1.8 inches, 128\u2009x\u2009160\u2009px Display',
#         '0.3\u2009MP Rear Camera'],
#        [None,
#         '6.1 inches, 1170\u2009x\u20092532\u2009px Display with Large Notch',
#         '12\u2009MP + 12\u2009MP + 12\u2009MP Triple Rear & 12\u2009MP Front Camera',
#         'Memory Card Not Supported', 'iOS v14.0'],
#        [None, '1.77 inches, 128\u2009x\u2009160\u2009px Display',
#         'No Rear Camera', 'Memory Card Supported, upto 32\u2009GB',
#         'Bluetooth'],
#        [None, '5\u2009MP Rear & 5\u2009MP Front Camera',
#         'Memory Card Supported, upto 32\u2009GB', 'Kaios v3.0',
#         'Bluetooth'],
#        [None, '1.8 inches, 160\u2009x\u2009128\u2009px Display',
#         'No Rear Camera', 'Memory Card Supported, upto 32\u2009GB', nan],
#        [None, '0.49 inches, 64\u2009x\u200932\u2009px Display',
#         'No Rear Camera', 'No FM Radio', 'Bluetooth'],
#        [None, '1.8 inches, 160\u2009x\u2009128\u2009px Display',
#         'No Rear Camera', 'Memory Card Supported, upto 32\u2009GB',
#         'Bluetooth'],
#        [None, 'No Rear Camera', 'No FM Radio', nan, nan],
#        [None, '0.3\u2009MP Rear & 0.3\u2009MP Front Camera',
#         'Memory Card Supported, upto 64\u2009GB', 'Bluetooth', 'Browser'],
#        [None, '1.8 inches, 128\u2009x\u2009160\u2009px Display',
#         'No Rear Camera', 'Memory Card Supported, upto 16\u2009GB',
#         'Bluetooth'],
#        [None, '6.1 inches, 750\u2009x\u20091580\u2009px Display',
#         '12\u2009MP Rear & 10.8\u2009MP Front Camera',
#         'Memory Card Not Supported', 'iOS v16'],
#        [None, '48\u2009MB RAM, 128\u2009MB inbuilt',
#         '1200\u2009mAh Battery',
#         '2.4 inches, 240\u2009x\u2009320\u2009px Display',
#         '1.3\u2009MP Rear Camera'],
#        [None,
#         '6.1 inches, 1170\u2009x\u20092532\u2009px Display with Large Notch',
#         '12\u2009MP + 12\u2009MP + 12\u2009MP Triple Rear & 12\u2009MP Front Camera',
#         'Memory Card Not Supported', 'iOS v14.0'],
#        [None, '2.8 inches, 240\u2009x\u2009320\u2009px Display',
#         '2\u2009MP Rear Camera', 'Memory Card Supported', 'Bluetooth'],
#        [None, '48\u2009MB RAM, 128\u2009MB inbuilt',
#         '1450\u2009mAh Battery',
#         '2.4 inches, 240\u2009x\u2009320\u2009px Display',
#         '0.3\u2009MP Rear Camera'],
#        [None, '5.4 inches, 1080\u2009x\u20092340\u2009px Display',
#         '12\u2009MP + 12\u2009MP Dual Rear & 12\u2009MP Front Camera',
#         'Memory Card Not Supported', 'iOS v14'],
#        [None,
#         '6.1 inches, 1170\u2009x\u20092532\u2009px Display with Large Notch',
#         '12\u2009MP + 12\u2009MP Dual Rear & 12\u2009MP Front Camera',
#         'Memory Card Not Supported', 'iOS v14'],
#        [None, '2.4 inches, 240\u2009x\u2009320\u2009px Display',
#         '2\u2009MP Rear Camera',
#         'Memory Card Supported, upto 32\u2009GB', 'Bluetooth'],
#        [None, '1.5 inches, 128\u2009x\u2009128\u2009px Display',
#         'No Rear Camera', 'No FM Radio', nan],
#        [None, '2.4 inches, 240\u2009x\u2009360\u2009px Display',
#         '0.3\u2009MP Rear Camera',
#         'Memory Card Supported, upto 128\u2009GB', 'Bluetooth'],
#        [None, '2.4 inches, 240\u2009x\u2009320\u2009px Display',
#         '0.3\u2009MP Rear Camera',
#         'Memory Card Supported, upto 32\u2009GB', 'Bluetooth'],
#        [None, '32\u2009MB RAM, 32\u2009MB inbuilt',
#         '800\u2009mAh Battery',
#         '1.77 inches, 240\u2009x\u2009320\u2009px Display',
#         'Dual Display']], dtype=object)

# %%
x = df1.loc[temp_df.index,temp_df.columns[7:]].shape

# %%
len(display_rows)
# Out:
# 27

# %%
len(camera_rows)
# Out:
# 64

# %%
df1[df1['index'].isin(display_rows)]
# Out:
#       index                         model   price  rating  \
# 439     441        Apple iPhone SE 3 2022   43900     NaN
# 448     450           Apple iPhone 15 Pro  130990    75.0
# 551     553               itel Magic 2 4G    2399     NaN
# 608     610             Namotel Achhe Din      99     NaN
# 611     613               Eunity U1 5605N     699     NaN
# 628     630   Apple iPhone 12 Pro (512GB)  139900    80.0
# 640     642                Nokia 105 Plus    1299     NaN
# 645     647               Nokia 2760 Flip    5490     NaN
# 647     649             Motorola Moto A10    1339     NaN
# 657     659                 Zanco Tiny T1    2799     NaN
# 665     667                  itel it2163S     958     NaN
# 699     701         Samsung Guru GT-E1215    1850     NaN
# 748     750                  Nokia 400 4G    3290     NaN
# 757     759                  Karbonn KU3i     995     NaN
# 762     764             Apple iPhone SE 4   49990    60.0
# 817     819                  itel Magic X    2239     NaN
# 857     859                   LG Folder 2   11999     NaN
# 882     884        Nokia 5710 XpressAudio    4799     NaN
# 913     915  Apple iPhone 12 Mini (256GB)   55999    75.0
# 914     916       Apple iPhone 12 (256GB)   67999    76.0
# 925     927                 Nokia 3310 4G    3999     NaN
# 927     929            Samsung Guru E1200    1685     NaN
# 930     932              iKall K88 Pro 4G    2099     NaN
# 988     990           Nokia 5310 Dual Sim    3399     NaN
# 1000   1002               XTouch F40 Flip    1999     NaN
#
#                                           sim  \
# 439   Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 448   Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 551            Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 608                       Dual Sim, 3G, Wi-Fi
# 611                                  Dual Sim
# 628   Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 640                                  Dual Sim
# 645                   Dual Sim, 3G, 4G, Wi-Fi
# 647                                  Dual Sim
# 657                                Single Sim
# 665                                  Dual Sim
# 699                                Single Sim
# 748                Dual Sim, 4G, VoLTE, Wi-Fi
# 757                                  Dual Sim
# 762   Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 817            Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 857                 Single Sim, 3G, 4G, Wi-Fi
# 882                          Dual Sim, 3G, 4G
# 913   Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 914   Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 925            Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 927                                Single Sim
# 930                   Dual Sim, 3G, 4G, VoLTE
# 988                                  Dual Sim
# 1000                                 Dual Sim
#
#                                        processor  \
# 439   Bionic  A15, Hexa Core, 3.22 GHz Processor
# 448                                  Bionic  A16
# 551                                        No 3G
# 608                       1 GB RAM, 4 GB inbuilt
# 611                                        No 3G
# 628     Bionic A14, Hexa Core, 3.1 GHz Processor
# 640                       4 MB RAM, 4 MB inbuilt
# 645                             1450 mAh Battery
# 647                       4 MB RAM, 4 MB inbuilt
# 657                     32 MB RAM, 32 MB inbuilt
# 665                       4 MB RAM, 4 MB inbuilt
# 699                              800 mAh Battery
# 748                             2000 mAh Battery
# 757                     52 MB RAM, 32 MB inbuilt
# 762   Bionic  A15, Hexa Core, 3.22 GHz Processor
# 817                                        No 3G
# 857                       1 GB RAM, 8 GB inbuilt
# 882                                      No Wifi
# 913     Bionic A14, Hexa Core, 3.1 GHz Processor
# 914     Bionic A14, Hexa Core, 3.1 GHz Processor
# 925                   256 MB RAM, 512 MB inbuilt
# 927                                      No Wifi
# 930                    48 MB RAM, 128 MB inbuilt
# 988                      8 MB RAM, 16 MB inbuilt
# 1000                                       No 3G
#
#                                    ram  \
# 439                      64 GB inbuilt
# 448           8 GB RAM, 128 GB inbuilt
# 551                               T117
# 608                   1325 mAh Battery
# 611       Dual Core, 500 MHz Processor
# 628           6 GB RAM, 512 GB inbuilt
# 640                    800 mAh Battery
# 645   3.6 inches, 240 x 320 px Display
# 647                   1750 mAh Battery
# 657                    200 mAh Battery
# 665                   1200 mAh Battery
# 699   1.5 inches, 120 x 120 px Display
# 748   2.4 inches, 240 x 320 px Display
# 757                   1000 mAh Battery
# 762                      64 GB inbuilt
# 817                               T117
# 857                   1470 mAh Battery
# 882                        Unisoc T107
# 913           4 GB RAM, 256 GB inbuilt
# 914           4 GB RAM, 256 GB inbuilt
# 925                   1200 mAh Battery
# 927                    800 mAh Battery
# 930                   1800 mAh Battery
# 988                   1200 mAh Battery
# 1000                           No Wifi
#
#                                                 battery  \
# 439                   4.7 inches, 750 x 1334 px Display
# 448   6.06 inches, 1170 x 2532 px, 120 Hz Display wi...
# 551                           64 MB RAM, 128 MB inbuilt
# 608                     4 inches, 720 x 1280 px Display
# 611                            32 MB RAM, 32 MB inbuilt
# 628   6.1 inches, 1170 x 2532 px Display with Large ...
# 640                   1.77 inches, 128 x 160 px Display
# 645                       5 MP Rear & 5 MP Front Camera
# 647                    1.8 inches, 160 x 128 px Display
# 657                     0.49 inches, 64 x 32 px Display
# 665                    1.8 inches, 160 x 128 px Display
# 699                                      No Rear Camera
# 748                   0.3 MP Rear & 0.3 MP Front Camera
# 757                    1.8 inches, 128 x 160 px Display
# 762                   6.1 inches, 750 x 1580 px Display
# 817                           48 MB RAM, 128 MB inbuilt
# 857                    2.8 inches, 240 x 320 px Display
# 882                           48 MB RAM, 128 MB inbuilt
# 913                  5.4 inches, 1080 x 2340 px Display
# 914   6.1 inches, 1170 x 2532 px Display with Large ...
# 925                    2.4 inches, 240 x 320 px Display
# 927                    1.5 inches, 128 x 128 px Display
# 930                    2.4 inches, 240 x 360 px Display
# 988                    2.4 inches, 240 x 320 px Display
# 1000                           32 MB RAM, 32 MB inbuilt
#
#                                                 display  \
# 439                      12 MP Rear & 7 MP Front Camera
# 448   50 MP + 12 MP + 12 MP Triple Rear & 12 MP Fron...
# 551                                    1900 mAh Battery
# 608                     2 MP Rear & 0.3 MP Front Camera
# 611                                    3000 mAh Battery
# 628   12 MP + 12 MP + 12 MP Triple Rear & 12 MP Fron...
# 640                                      No Rear Camera
# 645                   Memory Card Supported, upto 32 GB
# 647                                      No Rear Camera
# 657                                      No Rear Camera
# 665                                      No Rear Camera
# 699                                         No FM Radio
# 748                   Memory Card Supported, upto 64 GB
# 757                                      No Rear Camera
# 762                   12 MP Rear & 10.8 MP Front Camera
# 817                                    1200 mAh Battery
# 857                                    2 MP Rear Camera
# 882                                    1450 mAh Battery
# 913        12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 914        12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 925                                    2 MP Rear Camera
# 927                                      No Rear Camera
# 930                                  0.3 MP Rear Camera
# 988                                  0.3 MP Rear Camera
# 1000                                    800 mAh Battery
#
#                                   camera                card  \
# 439            Memory Card Not Supported             iOS v15
# 448            Memory Card Not Supported             iOS v15
# 551     2.4 inches, 240 x 320 px Display  1.3 MP Rear Camera
# 608              Android v5.0 (Lollipop)           Bluetooth
# 611     1.8 inches, 128 x 160 px Display  0.3 MP Rear Camera
# 628            Memory Card Not Supported           iOS v14.0
# 640    Memory Card Supported, upto 32 GB           Bluetooth
# 645                           Kaios v3.0           Bluetooth
# 647    Memory Card Supported, upto 32 GB                 NaN
# 657                          No FM Radio           Bluetooth
# 665    Memory Card Supported, upto 32 GB           Bluetooth
# 699                                  NaN                 NaN
# 748                            Bluetooth             Browser
# 757    Memory Card Supported, upto 16 GB           Bluetooth
# 762            Memory Card Not Supported             iOS v16
# 817     2.4 inches, 240 x 320 px Display  1.3 MP Rear Camera
# 857                Memory Card Supported           Bluetooth
# 882     2.4 inches, 240 x 320 px Display  0.3 MP Rear Camera
# 913            Memory Card Not Supported             iOS v14
# 914            Memory Card Not Supported             iOS v14
# 925    Memory Card Supported, upto 32 GB           Bluetooth
# 927                          No FM Radio                 NaN
# 930   Memory Card Supported, upto 128 GB           Bluetooth
# 988    Memory Card Supported, upto 32 GB           Bluetooth
# 1000   1.77 inches, 240 x 320 px Display        Dual Display
#
#                                      os
# 439                         No FM Radio
# 448                         No FM Radio
# 551   Memory Card Supported, upto 64 GB
# 608                                 NaN
# 611   Memory Card Supported, upto 16 GB
# 628                         No FM Radio
# 640                                 NaN
# 645                                 NaN
# 647                                 NaN
# 657                                 NaN
# 665                                 NaN
# 699                                 NaN
# 748                                 NaN
# 757                                 NaN
# 762                         No FM Radio
# 817   Memory Card Supported, upto 64 GB
# 857                                 NaN
# 882   Memory Card Supported, upto 32 GB
# 913                         No FM Radio
# 914                         No FM Radio
# 925                             Browser
# 927                                 NaN
# 930                             Browser
# 988                             Browser
# 1000                 1.3 MP Rear Camera

# %%
df1.drop([155,271], inplace=True)

# %%
temp_df = df1[df1['index'].isin(camera_rows)]

# %%
temp_df = temp_df[~temp_df['camera'].str.contains('MP')]
temp_df
# Out:
#       index                                     model   price  rating  \
# 98      100                            Vivo X Fold 5G  106990     NaN
# 111     113                           Apple iPhone 12   51999    74.0
# 149     151                      Apple iPhone 12 Mini   40999    74.0
# 159     161                           Oppo Find N2 5G   94990     NaN
# 236     238                      Xiaomi Mix Fold 2 5G  106990     NaN
# 306     308                   Samsung Galaxy Z Flip 3   69999    84.0
# 307     309                   Apple iPhone 12 (128GB)   55999    75.0
# 321     323                   Samsung Galaxy Z Fold 4  154998     NaN
# 322     324                          Royole FlexPai 2  109999    87.0
# 363     365              Apple iPhone 12 Mini (128GB)   45999    75.0
# 365     367                          OPPO Find N Flip   89990    88.0
# 392     394                         OPPO Find N2 Flip   70990    88.0
# 439     441                    Apple iPhone SE 3 2022   43900     NaN
# 448     450                       Apple iPhone 15 Pro  130990    75.0
# 482     484                          Vivo X Fold Plus  113990     NaN
# 504     506                Samsung Galaxy Z Flip 4 5G   89999    88.0
# 532     534             Samsung Guru Music 2 Dual Sim    1949     NaN
# 551     553                           itel Magic 2 4G    2399     NaN
# 569     571                   Samsung Galaxy Z Fold 3  110999    89.0
# 570     572                                LG Wing 5G   54999    89.0
# 573     575                          Nokia 105 (2019)    1299     NaN
# 608     610                         Namotel Achhe Din      99     NaN
# 611     613                           Eunity U1 5605N     699     NaN
# 613     615                              Oukitel WP21   22990    82.0
# 628     630               Apple iPhone 12 Pro (512GB)  139900    80.0
# 640     642                            Nokia 105 Plus    1299     NaN
# 645     647                           Nokia 2760 Flip    5490     NaN
# 647     649                         Motorola Moto A10    1339     NaN
# 657     659                             Zanco Tiny T1    2799     NaN
# 665     667                              itel it2163S     958     NaN
# 682     684                              LG V60 ThinQ   79990     NaN
# 685     687                              Xiaomi Qin 1    1799     NaN
# 703     705                            Oppo Find N 5G   92249     NaN
# 709     711                               OPPO X 2021  134999    86.0
# 721     723                Asus ROG Phone 6D Ultimate  107990     NaN
# 726     728                          Huawei Mate Xs 2  162990    89.0
# 748     750                              Nokia 400 4G    3290     NaN
# 757     759                              Karbonn KU3i     995     NaN
# 762     764                         Apple iPhone SE 4   49990    60.0
# 790     792                        Xiaomi Mi Mix Fold  109990     NaN
# 817     819                              itel Magic X    2239     NaN
# 844     846                              CAT S22 Flip   14999     NaN
# 852     854                              Nokia 215 4G    3099     NaN
# 853     855               Apple iPhone 12 Pro (256GB)  119900    80.0
# 881     883                          Nokia 110 (2022)    1599     NaN
# 882     884                    Nokia 5710 XpressAudio    4799     NaN
# 894     896                       Royole FlexPai 3 5G  149999    87.0
# 913     915              Apple iPhone 12 Mini (256GB)   55999    75.0
# 914     916                   Apple iPhone 12 (256GB)   67999    76.0
# 925     927                             Nokia 3310 4G    3999     NaN
# 927     929                        Samsung Guru E1200    1685     NaN
# 930     932                          iKall K88 Pro 4G    2099     NaN
# 943     945  Samsung Galaxy Z Fold 4 (12GB RAM + 1TB)  163980     NaN
# 954     956         Vivo X Fold 5G (12GB RAM + 512GB)  118990     NaN
# 988     990                       Nokia 5310 Dual Sim    3399     NaN
# 993     995                             Huawei Mate X  169000     NaN
# 1000   1002                           XTouch F40 Flip    1999     NaN
# 1014   1016                             Vivo X Fold 2  119990     NaN
#
#                                                     sim  \
# 98              Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 111             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 149             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 159             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 236   Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...
# 306           Single Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 307             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 321             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 322                  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 363             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 365           Single Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 392           Single Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 439             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 448             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 482             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 504             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 532                                            Dual Sim
# 551                      Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 569             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 570             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 573                                          Single Sim
# 608                                 Dual Sim, 3G, Wi-Fi
# 611                                            Dual Sim
# 613                      Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 628             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 640                                            Dual Sim
# 645                             Dual Sim, 3G, 4G, Wi-Fi
# 647                                            Dual Sim
# 657                                          Single Sim
# 665                                            Dual Sim
# 682             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 685                                     Dual Sim, Wi-Fi
# 703             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 709                    Single Sim, 3G, 4G, VoLTE, Wi-Fi
# 721             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 726     Dual Sim, 3G, 4G, VoLTE, Wi-Fi, NFC, IR Blaster
# 748                          Dual Sim, 4G, VoLTE, Wi-Fi
# 757                                            Dual Sim
# 762             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 790   Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...
# 817                      Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 844                    Single Sim, 3G, 4G, VoLTE, Wi-Fi
# 852                             Dual Sim, 3G, 4G, VoLTE
# 853             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 881                                            Dual Sim
# 882                                    Dual Sim, 3G, 4G
# 894                  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 913             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 914             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 925                      Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 927                                          Single Sim
# 930                             Dual Sim, 3G, 4G, VoLTE
# 943             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 954             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 988                                            Dual Sim
# 993   Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...
# 1000                                           Dual Sim
# 1014            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
#
#                                               processor  \
# 98        Snapdragon 8 Gen1, Octa Core, 3 GHz Processor
# 111            Bionic A14, Hexa Core, 3.1 GHz Processor
# 149            Bionic A14, Hexa Core, 3.1 GHz Processor
# 159    Snapdragon 8+ Gen1, Octa Core, 3.2 GHz Processor
# 236   Snapdragon  8+ Gen1 , Octa Core, 3.2 GHz Proce...
# 306       Snapdragon 888, Octa Core, 2.84 GHz Processor
# 307            Bionic A14, Hexa Core, 3.1 GHz Processor
# 321   Snapdragon  8+ Gen1, Octa Core, 3.2 GHz Processor
# 322       Snapdragon 865, Octa Core, 2.84 GHz Processor
# 363            Bionic A14, Hexa Core, 3.1 GHz Processor
# 365       Dimensity 9000, Octa Core, 3.05 GHz Processor
# 392   Dimensity 9000 Plus, Octa Core, 3.2 GHz Processor
# 439          Bionic  A15, Hexa Core, 3.22 GHz Processor
# 448                                         Bionic  A16
# 482    Snapdragon 8+ Gen1, Octa Core, 3.2 GHz Processor
# 504   Snapdragon  8+ Gen1, Octa Core, 3.2 GHz Processor
# 532                                             No Wifi
# 551                                               No 3G
# 569       Snapdragon 888, Octa Core, 2.84 GHz Processor
# 570     Snapdragon  765G , Octa Core, 2.4 GHz Processor
# 573                                             No Wifi
# 608                              1 GB RAM, 4 GB inbuilt
# 611                                               No 3G
# 613             Helio G99, Octa Core, 2.2 GHz Processor
# 628            Bionic A14, Hexa Core, 3.1 GHz Processor
# 640                              4 MB RAM, 4 MB inbuilt
# 645                                    1450 mAh Battery
# 647                              4 MB RAM, 4 MB inbuilt
# 657                            32 MB RAM, 32 MB inbuilt
# 665                              4 MB RAM, 4 MB inbuilt
# 682      Snapdragon  865, Octa Core, 2.84 GHz Processor
# 685                                       Helio MT6260A
# 703      Snapdragon  888, Octa Core, 2.84 GHz Processor
# 709       Snapdragon 865, Octa Core, 2.84 GHz Processor
# 721   Dimensity 9000 Plus, Octa Core, 3.2 GHz Processor
# 726       Snapdragon 888, Octa Core, 2.84 GHz Processor
# 748                                    2000 mAh Battery
# 757                            52 MB RAM, 32 MB inbuilt
# 762          Bionic  A15, Hexa Core, 3.22 GHz Processor
# 790     Snapdragon  888 , Octa Core, 2.84 GHz Processor
# 817                                               No 3G
# 844          Qualcomm 215, Quad Core, 1.3 GHz Processor
# 852                                         Unisoc T117
# 853            Bionic A14, Hexa Core, 3.1 GHz Processor
# 881                                             No Wifi
# 882                                             No Wifi
# 894       Snapdragon 888, Octa Core, 2.84 GHz Processor
# 913            Bionic A14, Hexa Core, 3.1 GHz Processor
# 914            Bionic A14, Hexa Core, 3.1 GHz Processor
# 925                          256 MB RAM, 512 MB inbuilt
# 927                                             No Wifi
# 930                           48 MB RAM, 128 MB inbuilt
# 943   Snapdragon  8+ Gen1, Octa Core, 3.2 GHz Processor
# 954       Snapdragon 8 Gen1, Octa Core, 3 GHz Processor
# 988                             8 MB RAM, 16 MB inbuilt
# 993           Kirin  990, Octa Core, 2.86 GHz Processor
# 1000                                              No 3G
# 1014    Snapdragon 8 Gen2, Octa Core, 3.2 GHz Processor
#
#                                    ram  \
# 98           12 GB RAM, 256 GB inbuilt
# 111            4 GB RAM, 64 GB inbuilt
# 149            4 GB RAM, 64 GB inbuilt
# 159          12 GB RAM, 256 GB inbuilt
# 236          12 GB RAM, 256 GB inbuilt
# 306           8 GB RAM, 128 GB inbuilt
# 307           4 GB RAM, 128 GB inbuilt
# 321          12 GB RAM, 256 GB inbuilt
# 322           8 GB RAM, 128 GB inbuilt
# 363           4 GB RAM, 128 GB inbuilt
# 365           8 GB RAM, 128 GB inbuilt
# 392           8 GB RAM, 256 GB inbuilt
# 439                      64 GB inbuilt
# 448           8 GB RAM, 128 GB inbuilt
# 482          12 GB RAM, 256 GB inbuilt
# 504           8 GB RAM, 128 GB inbuilt
# 532     Single Core, 208 MHz Processor
# 551                               T117
# 569          12 GB RAM, 256 GB inbuilt
# 570           8 GB RAM, 128 GB inbuilt
# 573             4 MB RAM, 4 MB inbuilt
# 608                   1325 mAh Battery
# 611       Dual Core, 500 MHz Processor
# 613          12 GB RAM, 256 GB inbuilt
# 628           6 GB RAM, 512 GB inbuilt
# 640                    800 mAh Battery
# 645   3.6 inches, 240 x 320 px Display
# 647                   1750 mAh Battery
# 657                    200 mAh Battery
# 665                   1200 mAh Battery
# 682           8 GB RAM, 128 GB inbuilt
# 685            8 MB RAM, 16 MB inbuilt
# 703           8 GB RAM, 256 GB inbuilt
# 709           8 GB RAM, 256 GB inbuilt
# 721          16 GB RAM, 512 GB inbuilt
# 726           8 GB RAM, 512 GB inbuilt
# 748   2.4 inches, 240 x 320 px Display
# 757                   1000 mAh Battery
# 762                      64 GB inbuilt
# 790          12 GB RAM, 256 GB inbuilt
# 817                               T117
# 844            2 GB RAM, 16 GB inbuilt
# 852          64 MB RAM, 128 MB inbuilt
# 853           6 GB RAM, 256 GB inbuilt
# 881             4 MB RAM, 4 MB inbuilt
# 882                        Unisoc T107
# 894           8 GB RAM, 128 GB inbuilt
# 913           4 GB RAM, 256 GB inbuilt
# 914           4 GB RAM, 256 GB inbuilt
# 925                   1200 mAh Battery
# 927                    800 mAh Battery
# 930                   1800 mAh Battery
# 943            12 GB RAM, 1 TB inbuilt
# 954          12 GB RAM, 512 GB inbuilt
# 988                   1200 mAh Battery
# 993           8 GB RAM, 512 GB inbuilt
# 1000                           No Wifi
# 1014         12 GB RAM, 256 GB inbuilt
#
#                                                 battery  \
# 98              4600 mAh Battery with 66W Fast Charging
# 111   6.1 inches, 1170 x 2532 px Display with Large ...
# 149                  5.4 inches, 1080 x 2340 px Display
# 159             4520 mAh Battery with 67W Fast Charging
# 236             4500 mAh Battery with 67W Fast Charging
# 306             3300 mAh Battery with 15W Fast Charging
# 307   6.1 inches, 1170 x 2532 px Display with Large ...
# 321             4400 mAh Battery with 25W Fast Charging
# 322                                    4450 mAh Battery
# 363                  5.4 inches, 1080 x 2340 px Display
# 365             4300 mAh Battery with 44W Fast Charging
# 392             4300 mAh Battery with 44W Fast Charging
# 439                   4.7 inches, 750 x 1334 px Display
# 448   6.06 inches, 1170 x 2532 px, 120 Hz Display wi...
# 482             4730 mAh Battery with 80W Fast Charging
# 504             3700 mAh Battery with 25W Fast Charging
# 532                                     800 mAh Battery
# 551                           64 MB RAM, 128 MB inbuilt
# 569             4400 mAh Battery with 25W Fast Charging
# 570                 4000 mAh Battery with Fast Charging
# 573                                     800 mAh Battery
# 608                     4 inches, 720 x 1280 px Display
# 611                            32 MB RAM, 32 MB inbuilt
# 613             9800 mAh Battery with 66W Fast Charging
# 628   6.1 inches, 1170 x 2532 px Display with Large ...
# 640                   1.77 inches, 128 x 160 px Display
# 645                       5 MP Rear & 5 MP Front Camera
# 647                    1.8 inches, 160 x 128 px Display
# 657                     0.49 inches, 64 x 32 px Display
# 665                    1.8 inches, 160 x 128 px Display
# 682                 5000 mAh Battery with Fast Charging
# 685                                    1480 mAh Battery
# 703             4500 mAh Battery with 33W Fast Charging
# 709             4000 mAh Battery with 45W Fast Charging
# 721             6000 mAh Battery with 65W Fast Charging
# 726             4600 mAh Battery with 66W Fast Charging
# 748                   0.3 MP Rear & 0.3 MP Front Camera
# 757                    1.8 inches, 128 x 160 px Display
# 762                   6.1 inches, 750 x 1580 px Display
# 790             5020 mAh Battery with 67W Fast Charging
# 817                           48 MB RAM, 128 MB inbuilt
# 844                                    2000 mAh Battery
# 852                                    1150 mAh Battery
# 853   6.1 inches, 1170 x 2532 px Display with Large ...
# 881                                    1000 mAh Battery
# 882                           48 MB RAM, 128 MB inbuilt
# 894                                    3360 mAh Battery
# 913                  5.4 inches, 1080 x 2340 px Display
# 914   6.1 inches, 1170 x 2532 px Display with Large ...
# 925                    2.4 inches, 240 x 320 px Display
# 927                    1.5 inches, 128 x 128 px Display
# 930                    2.4 inches, 240 x 360 px Display
# 943             4400 mAh Battery with 25W Fast Charging
# 954             4600 mAh Battery with 66W Fast Charging
# 988                    2.4 inches, 240 x 320 px Display
# 993             4500 mAh Battery with 55W Fast Charging
# 1000                           32 MB RAM, 32 MB inbuilt
# 1014            4800 mAh Battery with 66W Fast Charging
#
#                                                 display  \
# 98          8.03 inches, 1916 x 2160 px, 120 Hz Display
# 111        12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 149        12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 159   7.1 inches, 1792 x 1920 px, 120 Hz Display wit...
# 236   8.02 inches, 1914 x 2160 px, 120 Hz Display wi...
# 306   6.7 inches, 1080 x 2640 px, 120 Hz Display wit...
# 307        12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 321   7.6 inches, 1812 x 2176 px, 120 Hz Display wit...
# 322                  7.8 inches, 1440 x 1920 px Display
# 363        12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 365   6.8 inches, 1200 x 2400 px, 120 Hz Display wit...
# 392   6.8 inches, 1080 x 2520 px, 120 Hz Display wit...
# 439                      12 MP Rear & 7 MP Front Camera
# 448   50 MP + 12 MP + 12 MP Triple Rear & 12 MP Fron...
# 482   8.03 inches, 1916 x 2160 px, 120 Hz Display wi...
# 504   6.7 inches, 1080 x 2640 px, 120 Hz Display wit...
# 532                      2 inches, 128 x 160 px Display
# 551                                    1900 mAh Battery
# 569   7.6 inches, 1768 x 2208 px, 120 Hz Display wit...
# 570                  6.8 inches, 1080 x 2460 px Display
# 573                   1.77 inches, 120 x 160 px Display
# 608                     2 MP Rear & 0.3 MP Front Camera
# 611                                    3000 mAh Battery
# 613         6.78 inches, 1080 x 2400 px, 120 Hz Display
# 628   12 MP + 12 MP + 12 MP Triple Rear & 12 MP Fron...
# 640                                      No Rear Camera
# 645                   Memory Card Supported, upto 32 GB
# 647                                      No Rear Camera
# 657                                      No Rear Camera
# 665                                      No Rear Camera
# 682   6.8 inches, 1080 x 2460 px Display with Punch ...
# 685                    2.8 inches, 240 x 320 px Display
# 703   7.1 inches, 1792 x 1920 px, 120 Hz Display wit...
# 709                  7.4 inches, 1440 x 3200 px Display
# 721         6.78 inches, 1080 x 2448 px, 165 Hz Display
# 726   7.8 inches, 2200 x 2480 px, 120 Hz Display wit...
# 748                   Memory Card Supported, upto 64 GB
# 757                                      No Rear Camera
# 762                   12 MP Rear & 10.8 MP Front Camera
# 790          8.01 inches, 1860 x 2480 px, 90 Hz Display
# 817                                    1200 mAh Battery
# 844                      4 inches, 480 x 640 px Display
# 852                    2.4 inches, 240 x 320 px Display
# 853   12 MP + 12 MP + 12 MP Triple Rear & 12 MP Fron...
# 881                   1.77 inches, 120 x 160 px Display
# 882                                    1450 mAh Battery
# 894                  7.2 inches, 1440 x 1920 px Display
# 913        12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 914        12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 925                                    2 MP Rear Camera
# 927                                      No Rear Camera
# 930                                  0.3 MP Rear Camera
# 943   7.6 inches, 1812 x 2176 px, 120 Hz Display wit...
# 954         8.03 inches, 1916 x 2160 px, 120 Hz Display
# 988                                  0.3 MP Rear Camera
# 993                    8 inches, 2200 x 2480 px Display
# 1000                                    800 mAh Battery
# 1014        8.03 inches, 1916 x 2160 px, 120 Hz Display
#
#                                   camera  \
# 98                      Foldable Display
# 111            Memory Card Not Supported
# 149            Memory Card Not Supported
# 159       Foldable Display, Dual Display
# 236       Foldable Display, Dual Display
# 306       Foldable Display, Dual Display
# 307            Memory Card Not Supported
# 321       Foldable Display, Dual Display
# 322       Foldable Display, Dual Display
# 363            Memory Card Not Supported
# 365       Foldable Display, Dual Display
# 392       Foldable Display, Dual Display
# 439            Memory Card Not Supported
# 448            Memory Card Not Supported
# 482       Foldable Display, Dual Display
# 504       Foldable Display, Dual Display
# 532                       No Rear Camera
# 551     2.4 inches, 240 x 320 px Display
# 569       Foldable Display, Dual Display
# 570                         Dual Display
# 573                       No Rear Camera
# 608              Android v5.0 (Lollipop)
# 611     1.8 inches, 128 x 160 px Display
# 613                         Dual Display
# 628            Memory Card Not Supported
# 640    Memory Card Supported, upto 32 GB
# 645                           Kaios v3.0
# 647    Memory Card Supported, upto 32 GB
# 657                          No FM Radio
# 665    Memory Card Supported, upto 32 GB
# 682                         Dual Display
# 685                       No Rear Camera
# 703       Foldable Display, Dual Display
# 709                         Dual Display
# 721                         Dual Display
# 726                     Foldable Display
# 748                            Bluetooth
# 757    Memory Card Supported, upto 16 GB
# 762            Memory Card Not Supported
# 790       Foldable Display, Dual Display
# 817     2.4 inches, 240 x 320 px Display
# 844                         Dual Display
# 852                       No Rear Camera
# 853            Memory Card Not Supported
# 881    Memory Card Supported, upto 32 GB
# 882     2.4 inches, 240 x 320 px Display
# 894       Foldable Display, Dual Display
# 913            Memory Card Not Supported
# 914            Memory Card Not Supported
# 925    Memory Card Supported, upto 32 GB
# 927                          No FM Radio
# 930   Memory Card Supported, upto 128 GB
# 943       Foldable Display, Dual Display
# 954                     Foldable Display
# 988    Memory Card Supported, upto 32 GB
# 993                     Foldable Display
# 1000   1.77 inches, 240 x 320 px Display
# 1014                    Foldable Display
#
#                                                    card  \
# 98                 50 MP Quad Rear & 16 MP Front Camera
# 111                                             iOS v14
# 149                                             iOS v14
# 159   50 MP + 48 MP + 32 MP Triple Rear & 32 MP + 32...
# 236   50 MP + 13 MP + 8 MP Triple Rear & 20 MP Front...
# 306        12 MP + 12 MP Dual Rear & 10 MP Front Camera
# 307                                             iOS v14
# 321   50 MP + 12 MP + 10 MP Triple Rear & 10 MP + 4 ...
# 322   64 MP + 16 MP + 8 MP Triple Rear & 32 MP Front...
# 363                                             iOS v14
# 365         50 MP + 8 MP Dual Rear & 32 MP Front Camera
# 392         50 MP + 8 MP Dual Rear & 32 MP Front Camera
# 439                                             iOS v15
# 448                                             iOS v15
# 482   50 MP Quad Rear & 16 MP + 16 MP Dual Front Camera
# 504        12 MP + 12 MP Dual Rear & 10 MP Front Camera
# 532                   Memory Card Supported, upto 16 GB
# 551                                  1.3 MP Rear Camera
# 569   12 MP + 12 MP + 12 MP Triple Rear & 10 MP + 4 ...
# 570   64 MP + 13 MP + 12 MP Triple Rear & 32 MP Fron...
# 573                                                 NaN
# 608                                           Bluetooth
# 611                                  0.3 MP Rear Camera
# 613   64 MP + 20 MP + 2 MP Triple Rear & Main Front ...
# 628                                           iOS v14.0
# 640                                           Bluetooth
# 645                                           Bluetooth
# 647                                                 NaN
# 657                                           Bluetooth
# 665                                           Bluetooth
# 682   64 MP + 13 MP + 0.3 MP Triple Rear & 10 MP Fro...
# 685                                             Nucleus
# 703   50 MP + 16 MP + 13 MP Triple Rear & 32 MP Fron...
# 709   64 MP + 16 MP + 12 MP Triple Rear & 16 MP Fron...
# 721   50 MP + 13 MP + 5 MP Triple Rear & 12 MP Front...
# 726   50 MP + 13 MP + 8 MP Triple Rear & 10.7 MP Fro...
# 748                                             Browser
# 757                                           Bluetooth
# 762                                             iOS v16
# 790   108 MP + 13 MP + 8 MP Triple Rear & 20 MP Fron...
# 817                                  1.3 MP Rear Camera
# 844                       5 MP Rear & 2 MP Front Camera
# 852                   Memory Card Supported, upto 32 GB
# 853                                           iOS v14.0
# 881                                                 NaN
# 882                                  0.3 MP Rear Camera
# 894   64 MP + 16 MP + 8 MP Triple Rear & 32 MP Front...
# 913                                             iOS v14
# 914                                             iOS v14
# 925                                           Bluetooth
# 927                                                 NaN
# 930                                           Bluetooth
# 943   50 MP + 12 MP + 10 MP Triple Rear & 10 MP + 4 ...
# 954                50 MP Quad Rear & 16 MP Front Camera
# 988                                           Bluetooth
# 993                              48 MP Quad Rear Camera
# 1000                                       Dual Display
# 1014  50 MP + 50 MP + 10 MP Triple Rear & 32 MP Fron...
#
#                                       os
# 98                           Android v12
# 111                          No FM Radio
# 149                          No FM Radio
# 159            Memory Card Not Supported
# 236                          Android v12
# 306            Memory Card Not Supported
# 307                          No FM Radio
# 321                          Android v12
# 322   Memory Card Supported, upto 256 GB
# 363                          No FM Radio
# 365            Memory Card Not Supported
# 392            Memory Card Not Supported
# 439                          No FM Radio
# 448                          No FM Radio
# 482                          Android v12
# 504            Memory Card Not Supported
# 532                                  NaN
# 551    Memory Card Supported, upto 64 GB
# 569                          Android v11
# 570      Memory Card (Hybrid), upto 2 TB
# 573                                  NaN
# 608                                  NaN
# 611    Memory Card Supported, upto 16 GB
# 613                 Memory Card (Hybrid)
# 628                          No FM Radio
# 640                                  NaN
# 645                                  NaN
# 647                                  NaN
# 657                                  NaN
# 665                                  NaN
# 682      Memory Card (Hybrid), upto 2 TB
# 685                          No FM Radio
# 703                          Android v11
# 709                          Android v11
# 721            Memory Card Not Supported
# 726    Memory Card (Hybrid), upto 256 GB
# 748                                  NaN
# 757                                  NaN
# 762                          No FM Radio
# 790                          Android v10
# 817    Memory Card Supported, upto 64 GB
# 844   Memory Card Supported, upto 128 GB
# 852                    RTOS (Series 30+)
# 853                          No FM Radio
# 881                                  NaN
# 882    Memory Card Supported, upto 32 GB
# 894   Memory Card Supported, upto 256 GB
# 913                          No FM Radio
# 914                          No FM Radio
# 925                              Browser
# 927                                  NaN
# 930                              Browser
# 943                          Android v12
# 954                          Android v12
# 988                              Browser
# 993    Memory Card (Hybrid), upto 256 GB
# 1000                  1.3 MP Rear Camera
# 1014                         Android v12

# %%
df1.loc[temp_df.index,'camera'] = temp_df['card'].values

# %%
df1.loc[temp_df.index,'card'] = 'Memory Card Not Supported'

# %%
df1['card'].value_counts()
# Out:
# card
# Memory Card Supported, upto 1 TB                         171
# Memory Card Not Supported                                170
# Android v12                                              107
# Memory Card Supported, upto 512 GB                       105
# Memory Card (Hybrid), upto 1 TB                           91
# Memory Card Supported                                     89
# Memory Card Supported, upto 256 GB                        87
# Android v13                                               46
# Android v11                                               41
# Memory Card (Hybrid)                                      30
# Memory Card (Hybrid), upto 256 GB                         13
# Android v10                                               11
# Memory Card (Hybrid), upto 512 GB                         11
# Memory Card Supported, upto 128 GB                         7
# Memory Card Supported, upto 32 GB                          7
# Memory Card Supported, upto 2 TB                           5
# Memory Card (Hybrid), upto 64 GB                           3
# Memory Card (Hybrid), upto 128 GB                          3
# Android v9.0 (Pie)                                         2
# Memory Card Supported, upto 64 GB                          2
# iOS v13                                                    1
# Memory Card (Hybrid), upto 2 TB                            1
# Memory Card Supported, upto 48 GB                          1
# Bluetooth                                                  1
# HarmonyOS v2.0                                             1
# Memory Card Supported, upto 1000 GB                        1
# Android v10.0                                              1
# iOS v10                                                    1
# Android v12.1                                              1
# 64 MP + 10 MP + 8 MP Triple Rear & 32 MP Front Camera      1
# HarmonyOS                                                  1
# Name: count, dtype: int64

# %%
df1['camera'].value_counts()
# Out:
# camera
# 50 MP + 8 MP + 2 MP Triple Rear & 16 MP Front Camera           40
# 64 MP + 8 MP + 2 MP Triple Rear & 16 MP Front Camera           38
# 50 MP + 2 MP + 2 MP Triple Rear & 16 MP Front Camera           34
# 13 MP + 2 MP Dual Rear & 5 MP Front Camera                     23
# 50 MP + 2 MP + 2 MP Triple Rear & 8 MP Front Camera            20
#                                                                ..
# 48 MP + 2 MP + 2 MP Triple Rear & 32 MP Front Camera            1
# 64 MP + 12 MP + 2 MP Triple Rear & 16 MP Front Camera           1
# 50 MP + 50 MP + 16 MP Triple Rear & 16 MP Front Camera          1
# 48 MP + 5 MP + 2 MP Triple Rear & 8 MP Front Camera             1
# 48 MP + 2 MP + Depth Sensor Triple Rear & 8 MP Front Camera     1
# Name: count, Length: 296, dtype: int64

# %%
pd.set_option('display.max_colwidth', None)

# %%
df1[df1['card'].str.contains('Android', na=False)]
# Out:
#       index                        model  price  rating  \
# 8        10              Nothing Phone 1  26749    85.0
# 9        11           OnePlus Nord 2T 5G  28999    84.0
# 12       14  Xiaomi Redmi Note 12 Pro 5G  24762    79.0
# 17       19         OPPO Reno 9 Pro Plus  45999    86.0
# 18       20               OnePlus 10R 5G  32999    86.0
# ...     ...                          ...    ...     ...
# 1009   1011                Xiaomi Civi 3  32990    86.0
# 1011   1013                 Oppo Find X6  69990    89.0
# 1012   1014                    itel A23s   4787     NaN
# 1013   1015           Google Pixel 8 Pro  70990    80.0
# 1015   1017   Motorola Moto Edge S30 Pro  34990    83.0
#
#                                                       sim  \
# 8                 Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 9                 Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 12         Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, IR Blaster
# 17                Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 18                Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# ...                                                   ...
# 1009  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Blaster
# 1011              Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 1012                              Dual Sim, 3G, 4G, Wi-Fi
# 1013              Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 1015                   Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
#
#                                                processor  \
# 8     Snapdragon 778G Plus, Octa Core, 2.5 GHz Processor
# 9            Dimensity  1300, Octa Core, 3 GHz Processor
# 12          Dimensity 1080, Octa Core, 2.6 GHz Processor
# 17      Snapdragon 8+ Gen1, Octa Core, 3.2 GHz Processor
# 18     Dimensity 8100 Max, Octa Core, 2.85 GHz Processor
# ...                                                  ...
# 1009        Dimensity 8200, Octa Core, 3.1 GHz Processor
# 1011     Snapdragon 8 Gen2, Octa Core, 3.2 GHz Processor
# 1012   Spreadtrum  SC9832E, Quad Core, 1.4 GHz Processor
# 1013               Google  Tensor 3, Octa Core Processor
# 1015       Snapdragon 8 Gen1, Octa Core, 3 GHz Processor
#
#                             ram                                    battery  \
# 8      8 GB RAM, 128 GB inbuilt    4500 mAh Battery with 33W Fast Charging
# 9      8 GB RAM, 128 GB inbuilt    4500 mAh Battery with 80W Fast Charging
# 12     6 GB RAM, 128 GB inbuilt    5000 mAh Battery with 67W Fast Charging
# 17    16 GB RAM, 256 GB inbuilt    4700 mAh Battery with 80W Fast Charging
# 18     8 GB RAM, 128 GB inbuilt    5000 mAh Battery with 80W Fast Charging
# ...                         ...                                        ...
# 1009   8 GB RAM, 256 GB inbuilt    5000 mAh Battery with 80W Fast Charging
# 1011   8 GB RAM, 256 GB inbuilt   4700 mAh Battery with 120W Fast Charging
# 1012    2 GB RAM, 32 GB inbuilt                           3020 mAh Battery
# 1013  12 GB RAM, 256 GB inbuilt    5000 mAh Battery with 67W Fast Charging
# 1015   8 GB RAM, 128 GB inbuilt  5000 mAh Battery with 68.2W Fast Charging
#
#                                                           display  \
# 8     6.55 inches, 1080 x 2400 px, 120 Hz Display with Punch Hole
# 9      6.43 inches, 1080 x 2400 px, 90 Hz Display with Punch Hole
# 12    6.67 inches, 1080 x 2400 px, 120 Hz Display with Punch Hole
# 17     6.7 inches, 1080 x 2412 px, 120 Hz Display with Punch Hole
# 18     6.7 inches, 1080 x 2412 px, 120 Hz Display with Punch Hole
# ...                                                           ...
# 1009   6.7 inches, 1080 x 2400 px, 120 Hz Display with Punch Hole
# 1011  6.73 inches, 1080 x 2400 px, 120 Hz Display with Punch Hole
# 1012                               5 inches, 854 x 480 px Display
# 1013  6.73 inches, 1440 x 3120 px, 120 Hz Display with Punch Hole
# 1015  6.67 inches, 1080 x 2460 px, 120 Hz Display with Punch Hole
#
#                                                                   camera  \
# 8                           50 MP + 50 MP Dual Rear & 16 MP Front Camera
# 9                   50 MP + 8 MP + 2 MP Triple Rear & 32 MP Front Camera
# 12                  50 MP + 8 MP + 2 MP Triple Rear & 16 MP Front Camera
# 17                  50 MP + 8 MP + 2 MP Triple Rear & 32 MP Front Camera
# 18                  50 MP + 8 MP + 2 MP Triple Rear & 16 MP Front Camera
# ...                                                                  ...
# 1009  64 MP + 20 MP + 2 MP Triple Rear & 32 MP + 32 MP Dual Front Camera
# 1011              50 MP + 48 MP + 32 MP Triple Rear & 32 MP Front Camera
# 1012                                                    2 MP Rear Camera
# 1013              50 MP + 50 MP + 50 MP Triple Rear & 12 MP Front Camera
# 1015                64 MP + 8 MP + 2 MP Triple Rear & 16 MP Front Camera
#
#              card           os
# 8     Android v12  No FM Radio
# 9     Android v12  No FM Radio
# 12    Android v12  No FM Radio
# 17    Android v13  No FM Radio
# 18    Android v12    Bluetooth
# ...           ...          ...
# 1009  Android v13  No FM Radio
# 1011  Android v12  No FM Radio
# 1012  Android v11  No FM Radio
# 1013  Android v13  No FM Radio
# 1015  Android v12  No FM Radio
#
# [209 rows x 12 columns]

# %%
temp_df = df1[~df1['card'].str.contains('Memory Card', na=False)]

# %%
df1.loc[temp_df.index,'os'] = temp_df['card'].values

# %%
df1.head(9
)
# Out:
#    index                                    model  price  rating  \
# 0      2                            OnePlus 11 5G  54999    89.0
# 1      3                OnePlus Nord CE 2 Lite 5G  19989    81.0
# 2      4                    Samsung Galaxy A14 5G  16499    75.0
# 3      5                     Motorola Moto G62 5G  14999    81.0
# 4      6                       Realme 10 Pro Plus  24999    82.0
# 5      7  Samsung Galaxy F23 5G (6GB RAM + 128GB)  16999    80.0
# 6      8                          Apple iPhone 14  65999    81.0
# 7      9            Xiaomi Redmi Note 12 Pro Plus  29999    86.0
# 8     10                          Nothing Phone 1  26749    85.0
#
#                                               sim  \
# 0         Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 1              Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 2              Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 3              Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 4              Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 5         Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 6         Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 7  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, IR Blaster
# 8         Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
#
#                                             processor  \
# 0     Snapdragon 8 Gen2, Octa Core, 3.2 GHz Processor
# 1        Snapdragon 695, Octa Core, 2.2 GHz Processor
# 2           Exynos 1330, Octa Core, 2.4 GHz Processor
# 3       Snapdragon  695, Octa Core, 2.2 GHz Processor
# 4        Dimensity 1080, Octa Core, 2.6 GHz Processor
# 5      Snapdragon  750G, Octa Core, 2.2 GHz Processor
# 6           Bionic A15, Hexa Core, 3.22 GHz Processor
# 7        Dimensity 1080, Octa Core, 2.6 GHz Processor
# 8  Snapdragon 778G Plus, Octa Core, 2.5 GHz Processor
#
#                          ram                                   battery  \
# 0  12 GB RAM, 256 GB inbuilt  5000 mAh Battery with 100W Fast Charging
# 1   6 GB RAM, 128 GB inbuilt   5000 mAh Battery with 33W Fast Charging
# 2    4 GB RAM, 64 GB inbuilt   5000 mAh Battery with 15W Fast Charging
# 3   6 GB RAM, 128 GB inbuilt       5000 mAh Battery with Fast Charging
# 4   6 GB RAM, 128 GB inbuilt   5000 mAh Battery with 67W Fast Charging
# 5   6 GB RAM, 128 GB inbuilt   5000 mAh Battery with 25W Fast Charging
# 6   6 GB RAM, 128 GB inbuilt       3279 mAh Battery with Fast Charging
# 7   8 GB RAM, 256 GB inbuilt  4980 mAh Battery with 120W Fast Charging
# 8   8 GB RAM, 128 GB inbuilt   4500 mAh Battery with 33W Fast Charging
#
#                                                             display  \
# 0        6.7 inches, 1440 x 3216 px, 120 Hz Display with Punch Hole
# 1       6.59 inches, 1080 x 2412 px, 120 Hz Display with Punch Hole
# 2   6.6 inches, 1080 x 2408 px, 90 Hz Display with Water Drop Notch
# 3       6.55 inches, 1080 x 2400 px, 120 Hz Display with Punch Hole
# 4        6.7 inches, 1080 x 2412 px, 120 Hz Display with Punch Hole
# 5  6.6 inches, 1080 x 2408 px, 120 Hz Display with Water Drop Notch
# 6               6.1 inches, 1170 x 2532 px Display with Small Notch
# 7       6.67 inches, 1080 x 2400 px, 120 Hz Display with Punch Hole
# 8       6.55 inches, 1080 x 2400 px, 120 Hz Display with Punch Hole
#
#                                                    camera  \
# 0  50 MP + 48 MP + 32 MP Triple Rear & 16 MP Front Camera
# 1    64 MP + 2 MP + 2 MP Triple Rear & 16 MP Front Camera
# 2    50 MP + 2 MP + 2 MP Triple Rear & 13 MP Front Camera
# 3    50 MP + 8 MP + 2 MP Triple Rear & 16 MP Front Camera
# 4   108 MP + 8 MP + 2 MP Triple Rear & 16 MP Front Camera
# 5     50 MP + 8 MP + 2 MP Triple Rear & 8 MP Front Camera
# 6            12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 7   200 MP + 8 MP + 2 MP Triple Rear & 16 MP Front Camera
# 8            50 MP + 50 MP Dual Rear & 16 MP Front Camera
#
#                                card           os
# 0         Memory Card Not Supported  Android v13
# 1   Memory Card (Hybrid), upto 1 TB  Android v12
# 2  Memory Card Supported, upto 1 TB  Android v13
# 3   Memory Card (Hybrid), upto 1 TB  Android v12
# 4         Memory Card Not Supported  Android v13
# 5  Memory Card Supported, upto 1 TB  Android v12
# 6         Memory Card Not Supported      iOS v16
# 7         Memory Card Not Supported  Android v12
# 8                       Android v12  Android v12

# %%
df1.loc[temp_df.index,'card'] = 'Memory Card Not Supported'

# %%
df1
# Out:
#       index                            model  price  rating  \
# 0         2                    OnePlus 11 5G  54999    89.0
# 1         3        OnePlus Nord CE 2 Lite 5G  19989    81.0
# 2         4            Samsung Galaxy A14 5G  16499    75.0
# 3         5             Motorola Moto G62 5G  14999    81.0
# 4         6               Realme 10 Pro Plus  24999    82.0
# ...     ...                              ...    ...     ...
# 1015   1017       Motorola Moto Edge S30 Pro  34990    83.0
# 1016   1018                      Honor X8 5G  14990    75.0
# 1017   1019  POCO X4 GT 5G (8GB RAM + 256GB)  28990    85.0
# 1018   1020             Motorola Moto G91 5G  19990    80.0
# 1019   1021           Samsung Galaxy M52s 5G  24990    74.0
#
#                                                       sim  \
# 0                 Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 1                      Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 2                      Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 3                      Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 4                      Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# ...                                                   ...
# 1015                   Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 1016                   Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 1017  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Blaster
# 1018              Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 1019                   Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
#
#                                             processor  \
# 0     Snapdragon 8 Gen2, Octa Core, 3.2 GHz Processor
# 1        Snapdragon 695, Octa Core, 2.2 GHz Processor
# 2           Exynos 1330, Octa Core, 2.4 GHz Processor
# 3       Snapdragon  695, Octa Core, 2.2 GHz Processor
# 4        Dimensity 1080, Octa Core, 2.6 GHz Processor
# ...                                               ...
# 1015    Snapdragon 8 Gen1, Octa Core, 3 GHz Processor
# 1016   Snapdragon  480+, Octa Core, 2.2 GHz Processor
# 1017    Dimensity 8100, Octa Core, 2.85 GHz Processor
# 1018     Snapdragon 695, Octa Core, 2.2 GHz Processor
# 1019                              Octa Core Processor
#
#                             ram                                    battery  \
# 0     12 GB RAM, 256 GB inbuilt   5000 mAh Battery with 100W Fast Charging
# 1      6 GB RAM, 128 GB inbuilt    5000 mAh Battery with 33W Fast Charging
# 2       4 GB RAM, 64 GB inbuilt    5000 mAh Battery with 15W Fast Charging
# 3      6 GB RAM, 128 GB inbuilt        5000 mAh Battery with Fast Charging
# 4      6 GB RAM, 128 GB inbuilt    5000 mAh Battery with 67W Fast Charging
# ...                         ...                                        ...
# 1015   8 GB RAM, 128 GB inbuilt  5000 mAh Battery with 68.2W Fast Charging
# 1016   6 GB RAM, 128 GB inbuilt  5000 mAh Battery with 22.5W Fast Charging
# 1017   8 GB RAM, 256 GB inbuilt    5080 mAh Battery with 67W Fast Charging
# 1018   6 GB RAM, 128 GB inbuilt        5000 mAh Battery with Fast Charging
# 1019   8 GB RAM, 128 GB inbuilt        5000 mAh Battery with Fast Charging
#
#                                                               display  \
# 0          6.7 inches, 1440 x 3216 px, 120 Hz Display with Punch Hole
# 1         6.59 inches, 1080 x 2412 px, 120 Hz Display with Punch Hole
# 2     6.6 inches, 1080 x 2408 px, 90 Hz Display with Water Drop Notch
# 3         6.55 inches, 1080 x 2400 px, 120 Hz Display with Punch Hole
# 4          6.7 inches, 1080 x 2412 px, 120 Hz Display with Punch Hole
# ...                                                               ...
# 1015      6.67 inches, 1080 x 2460 px, 120 Hz Display with Punch Hole
# 1016          6.5 inches, 720 x 1600 px Display with Water Drop Notch
# 1017       6.6 inches, 1080 x 2460 px, 144 Hz Display with Punch Hole
# 1018               6.8 inches, 1080 x 2400 px Display with Punch Hole
# 1019         6.5 inches, 1080 x 2400 px Display with Water Drop Notch
#
#                                                            camera  \
# 0          50 MP + 48 MP + 32 MP Triple Rear & 16 MP Front Camera
# 1            64 MP + 2 MP + 2 MP Triple Rear & 16 MP Front Camera
# 2            50 MP + 2 MP + 2 MP Triple Rear & 13 MP Front Camera
# 3            50 MP + 8 MP + 2 MP Triple Rear & 16 MP Front Camera
# 4           108 MP + 8 MP + 2 MP Triple Rear & 16 MP Front Camera
# ...                                                           ...
# 1015         64 MP + 8 MP + 2 MP Triple Rear & 16 MP Front Camera
# 1016  48 MP + 2 MP + Depth Sensor Triple Rear & 8 MP Front Camera
# 1017         64 MP + 8 MP + 2 MP Triple Rear & 16 MP Front Camera
# 1018        108 MP + 8 MP + 2 MP Triple Rear & 32 MP Front Camera
# 1019         64 MP + 8 MP + 5 MP Triple Rear & 32 MP Front Camera
#
#                                   card           os
# 0            Memory Card Not Supported  Android v13
# 1      Memory Card (Hybrid), upto 1 TB  Android v12
# 2     Memory Card Supported, upto 1 TB  Android v13
# 3      Memory Card (Hybrid), upto 1 TB  Android v12
# 4            Memory Card Not Supported  Android v13
# ...                                ...          ...
# 1015         Memory Card Not Supported  Android v12
# 1016  Memory Card Supported, upto 1 TB  Android v11
# 1017         Memory Card Not Supported  Android v12
# 1018  Memory Card Supported, upto 1 TB  Android v12
# 1019  Memory Card Supported, upto 1 TB  Android v12
#
# [1015 rows x 12 columns]

# %%
df1['card'].value_counts()
# Out:
# card
# Memory Card Not Supported              388
# Memory Card Supported, upto 1 TB       171
# Memory Card Supported, upto 512 GB     105
# Memory Card (Hybrid), upto 1 TB         91
# Memory Card Supported                   89
# Memory Card Supported, upto 256 GB      87
# Memory Card (Hybrid)                    30
# Memory Card (Hybrid), upto 256 GB       13
# Memory Card (Hybrid), upto 512 GB       11
# Memory Card Supported, upto 128 GB       7
# Memory Card Supported, upto 32 GB        7
# Memory Card Supported, upto 2 TB         5
# Memory Card (Hybrid), upto 128 GB        3
# Memory Card (Hybrid), upto 64 GB         3
# Memory Card Supported, upto 64 GB        2
# Memory Card Supported, upto 1000 GB      1
# Memory Card Supported, upto 48 GB        1
# Memory Card (Hybrid), upto 2 TB          1
# Name: count, dtype: int64

# %%
df1['os'].value_counts()
# Out:
# os
# Android v12                                              393
# Android v11                                              274
# Android v13                                               91
# Android v10                                               69
# Android v9.0 (Pie)                                        29
# Android v10.0                                             23
# iOS v16                                                   14
# No FM Radio                                               12
# iOS v15                                                   10
# Android v8.1 (Oreo)                                       10
# Bluetooth                                                  6
# Memory Card Not Supported                                  6
# Android v11.0                                              4
# iOS v13                                                    4
# Android v8.0 (Oreo)                                        4
# iOS v15.0                                                  3
# Browser                                                    3
# Android v6.0 (Marshmallow)                                 3
# EMUI v12                                                   2
# Memory Card (Hybrid), upto 256 GB                          2
# Harmony v2.0                                               2
# RTOS (Series 30+)                                          2
# Memory Card (Hybrid), upto 2 TB                            2
# Memory Card Supported, upto 64 GB                          2
# HarmonyOS v2.0                                             2
# Android v5.1.1 (Lollipop)                                  2
# Android v12.1                                              2
# Memory Card Supported, upto 256 GB                         2
# Hongmeng OS v3.0                                           1
# Android v9 (Pie)                                           1
# Android                                                    1
# 64 MP + 10 MP + 8 MP Triple Rear & 32 MP Front Camera      1
# Android v7.1 (Nougat)                                      1
# HarmonyOS                                                  1
# Memory Card Supported, upto 32 GB                          1
# HarmonyOS v2                                               1
# Memory Card Supported, upto 128 GB                         1
# iOS v13.0                                                  1
# Hongmeng OS v4.0                                           1
# Android v5.1 (Lollipop)                                    1
# iOS v12.3                                                  1
# Memory Card (Hybrid)                                       1
# Memory Card Supported, upto 16 GB                          1
# iOS v10                                                    1
# Pragati OS (Powered by Android)                            1
# KAI OS                                                     1
# iOS v17                                                    1
# Android v4.4.2 (KitKat)                                    1
# 1.3 MP Rear Camera                                         1
# Name: count, dtype: int64

# %%
temp_df = df1[df1['os'].str.contains('Memory Card', na=False)]
temp_df
# Out:
#      index                       model   price  rating  \
# 159    161             Oppo Find N2 5G   94990     NaN
# 306    308     Samsung Galaxy Z Flip 3   69999    84.0
# 322    324            Royole FlexPai 2  109999    87.0
# 365    367            OPPO Find N Flip   89990    88.0
# 392    394           OPPO Find N2 Flip   70990    88.0
# 504    506  Samsung Galaxy Z Flip 4 5G   89999    88.0
# 551    553             itel Magic 2 4G    2399     NaN
# 570    572                  LG Wing 5G   54999    89.0
# 611    613             Eunity U1 5605N     699     NaN
# 613    615                Oukitel WP21   22990    82.0
# 682    684                LG V60 ThinQ   79990     NaN
# 721    723  Asus ROG Phone 6D Ultimate  107990     NaN
# 726    728            Huawei Mate Xs 2  162990    89.0
# 817    819                itel Magic X    2239     NaN
# 844    846                CAT S22 Flip   14999     NaN
# 882    884      Nokia 5710 XpressAudio    4799     NaN
# 894    896         Royole FlexPai 3 5G  149999    87.0
# 993    995               Huawei Mate X  169000     NaN
#
#                                                      sim  \
# 159              Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 306            Single Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 322                   Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 365            Single Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 392            Single Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 504              Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 551                       Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 570              Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 611                                             Dual Sim
# 613                       Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 682              Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 721              Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 726      Dual Sim, 3G, 4G, VoLTE, Wi-Fi, NFC, IR Blaster
# 817                       Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 844                     Single Sim, 3G, 4G, VoLTE, Wi-Fi
# 882                                     Dual Sim, 3G, 4G
# 894                   Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 993  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Blaster
#
#                                              processor  \
# 159   Snapdragon 8+ Gen1, Octa Core, 3.2 GHz Processor
# 306      Snapdragon 888, Octa Core, 2.84 GHz Processor
# 322      Snapdragon 865, Octa Core, 2.84 GHz Processor
# 365      Dimensity 9000, Octa Core, 3.05 GHz Processor
# 392  Dimensity 9000 Plus, Octa Core, 3.2 GHz Processor
# 504  Snapdragon  8+ Gen1, Octa Core, 3.2 GHz Processor
# 551                                              No 3G
# 570    Snapdragon  765G , Octa Core, 2.4 GHz Processor
# 611                                              No 3G
# 613            Helio G99, Octa Core, 2.2 GHz Processor
# 682     Snapdragon  865, Octa Core, 2.84 GHz Processor
# 721  Dimensity 9000 Plus, Octa Core, 3.2 GHz Processor
# 726      Snapdragon 888, Octa Core, 2.84 GHz Processor
# 817                                              No 3G
# 844         Qualcomm 215, Quad Core, 1.3 GHz Processor
# 882                                            No Wifi
# 894      Snapdragon 888, Octa Core, 2.84 GHz Processor
# 993          Kirin  990, Octa Core, 2.86 GHz Processor
#
#                               ram                                  battery  \
# 159     12 GB RAM, 256 GB inbuilt  4520 mAh Battery with 67W Fast Charging
# 306      8 GB RAM, 128 GB inbuilt  3300 mAh Battery with 15W Fast Charging
# 322      8 GB RAM, 128 GB inbuilt                         4450 mAh Battery
# 365      8 GB RAM, 128 GB inbuilt  4300 mAh Battery with 44W Fast Charging
# 392      8 GB RAM, 256 GB inbuilt  4300 mAh Battery with 44W Fast Charging
# 504      8 GB RAM, 128 GB inbuilt  3700 mAh Battery with 25W Fast Charging
# 551                          T117                64 MB RAM, 128 MB inbuilt
# 570      8 GB RAM, 128 GB inbuilt      4000 mAh Battery with Fast Charging
# 611  Dual Core, 500 MHz Processor                 32 MB RAM, 32 MB inbuilt
# 613     12 GB RAM, 256 GB inbuilt  9800 mAh Battery with 66W Fast Charging
# 682      8 GB RAM, 128 GB inbuilt      5000 mAh Battery with Fast Charging
# 721     16 GB RAM, 512 GB inbuilt  6000 mAh Battery with 65W Fast Charging
# 726      8 GB RAM, 512 GB inbuilt  4600 mAh Battery with 66W Fast Charging
# 817                          T117                48 MB RAM, 128 MB inbuilt
# 844       2 GB RAM, 16 GB inbuilt                         2000 mAh Battery
# 882                   Unisoc T107                48 MB RAM, 128 MB inbuilt
# 894      8 GB RAM, 128 GB inbuilt                         3360 mAh Battery
# 993      8 GB RAM, 512 GB inbuilt  4500 mAh Battery with 55W Fast Charging
#
#                                                         display  \
# 159  7.1 inches, 1792 x 1920 px, 120 Hz Display with Punch Hole
# 306  6.7 inches, 1080 x 2640 px, 120 Hz Display with Punch Hole
# 322                          7.8 inches, 1440 x 1920 px Display
# 365  6.8 inches, 1200 x 2400 px, 120 Hz Display with Punch Hole
# 392  6.8 inches, 1080 x 2520 px, 120 Hz Display with Punch Hole
# 504  6.7 inches, 1080 x 2640 px, 120 Hz Display with Punch Hole
# 551                                            1900 mAh Battery
# 570                          6.8 inches, 1080 x 2460 px Display
# 611                                            3000 mAh Battery
# 613                 6.78 inches, 1080 x 2400 px, 120 Hz Display
# 682          6.8 inches, 1080 x 2460 px Display with Punch Hole
# 721                 6.78 inches, 1080 x 2448 px, 165 Hz Display
# 726  7.8 inches, 2200 x 2480 px, 120 Hz Display with Punch Hole
# 817                                            1200 mAh Battery
# 844                              4 inches, 480 x 640 px Display
# 882                                            1450 mAh Battery
# 894                          7.2 inches, 1440 x 1920 px Display
# 993                            8 inches, 2200 x 2480 px Display
#
#                                                                   camera  \
# 159  50 MP + 48 MP + 32 MP Triple Rear & 32 MP + 32 MP Dual Front Camera
# 306                         12 MP + 12 MP Dual Rear & 10 MP Front Camera
# 322                64 MP + 16 MP + 8 MP Triple Rear & 32 MP Front Camera
# 365                          50 MP + 8 MP Dual Rear & 32 MP Front Camera
# 392                          50 MP + 8 MP Dual Rear & 32 MP Front Camera
# 504                         12 MP + 12 MP Dual Rear & 10 MP Front Camera
# 551                                                   1.3 MP Rear Camera
# 570               64 MP + 13 MP + 12 MP Triple Rear & 32 MP Front Camera
# 611                                                   0.3 MP Rear Camera
# 613                 64 MP + 20 MP + 2 MP Triple Rear & Main Front Camera
# 682              64 MP + 13 MP + 0.3 MP Triple Rear & 10 MP Front Camera
# 721                50 MP + 13 MP + 5 MP Triple Rear & 12 MP Front Camera
# 726              50 MP + 13 MP + 8 MP Triple Rear & 10.7 MP Front Camera
# 817                                                   1.3 MP Rear Camera
# 844                                        5 MP Rear & 2 MP Front Camera
# 882                                                   0.3 MP Rear Camera
# 894                64 MP + 16 MP + 8 MP Triple Rear & 32 MP Front Camera
# 993                                               48 MP Quad Rear Camera
#
#                           card                                  os
# 159  Memory Card Not Supported           Memory Card Not Supported
# 306  Memory Card Not Supported           Memory Card Not Supported
# 322  Memory Card Not Supported  Memory Card Supported, upto 256 GB
# 365  Memory Card Not Supported           Memory Card Not Supported
# 392  Memory Card Not Supported           Memory Card Not Supported
# 504  Memory Card Not Supported           Memory Card Not Supported
# 551  Memory Card Not Supported   Memory Card Supported, upto 64 GB
# 570  Memory Card Not Supported     Memory Card (Hybrid), upto 2 TB
# 611  Memory Card Not Supported   Memory Card Supported, upto 16 GB
# 613  Memory Card Not Supported                Memory Card (Hybrid)
# 682  Memory Card Not Supported     Memory Card (Hybrid), upto 2 TB
# 721  Memory Card Not Supported           Memory Card Not Supported
# 726  Memory Card Not Supported   Memory Card (Hybrid), upto 256 GB
# 817  Memory Card Not Supported   Memory Card Supported, upto 64 GB
# 844  Memory Card Not Supported  Memory Card Supported, upto 128 GB
# 882  Memory Card Not Supported   Memory Card Supported, upto 32 GB
# 894  Memory Card Not Supported  Memory Card Supported, upto 256 GB
# 993  Memory Card Not Supported   Memory Card (Hybrid), upto 256 GB

# %%
df1.loc[temp_df.index,'os'] = np.nan

# %%
df1['os'].value_counts()
# Out:
# os
# Android v12                                              393
# Android v11                                              274
# Android v13                                               91
# Android v10                                               69
# Android v9.0 (Pie)                                        29
# Android v10.0                                             23
# iOS v16                                                   14
# No FM Radio                                               12
# Android v8.1 (Oreo)                                       10
# iOS v15                                                   10
# Bluetooth                                                  6
# Android v8.0 (Oreo)                                        4
# Android v11.0                                              4
# iOS v13                                                    4
# Browser                                                    3
# iOS v15.0                                                  3
# Android v6.0 (Marshmallow)                                 3
# RTOS (Series 30+)                                          2
# Android v12.1                                              2
# EMUI v12                                                   2
# HarmonyOS v2.0                                             2
# Android v5.1.1 (Lollipop)                                  2
# Harmony v2.0                                               2
# Android v7.1 (Nougat)                                      1
# HarmonyOS                                                  1
# Android                                                    1
# Hongmeng OS v4.0                                           1
# Android v9 (Pie)                                           1
# Android v4.4.2 (KitKat)                                    1
# iOS v10                                                    1
# Pragati OS (Powered by Android)                            1
# Hongmeng OS v3.0                                           1
# Android v5.1 (Lollipop)                                    1
# iOS v17                                                    1
# KAI OS                                                     1
# iOS v12.3                                                  1
# iOS v13.0                                                  1
# HarmonyOS v2                                               1
# 64 MP + 10 MP + 8 MP Triple Rear & 32 MP Front Camera      1
# 1.3 MP Rear Camera                                         1
# Name: count, dtype: int64

# %%
df1[df1['os'].str.contains('Bluetooth',na = False)]
# Out:
#      index               model  price  rating                             sim  \
# 486    488       Nokia 8000 4G   6899     NaN         Dual Sim, 3G, 4G, Wi-Fi
# 533    535     Itel MagicX Pro   2799     NaN  Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 846    848       DIZO Star 500   1749     NaN                        Dual Sim
# 857    859         LG Folder 2  11999     NaN       Single Sim, 3G, 4G, Wi-Fi
# 873    875  BlackZone Ultra 4G   1899     NaN         Dual Sim, 3G, 4G, VoLTE
# 917    919    Nokia 150 (2020)   2499     NaN                        Dual Sim
#
#                                          processor                        ram  \
# 486  Snapdragon  210, Quad Core, 1.1 GHz Processor   512 MB RAM, 4 GB inbuilt
# 533                                1 GHz Processor  64 MB RAM, 128 MB inbuilt
# 846                      SC6531E, 26 MHz Processor   32 MB RAM, 32 MB inbuilt
# 857                         1 GB RAM, 8 GB inbuilt           1470 mAh Battery
# 873                   Single Core, 1 GHz Processor   48 MB RAM, 48 MB inbuilt
# 917                                        No Wifi               4 MB inbuilt
#
#                               battery                           display  \
# 486                  1500 mAh Battery  2.8 inches, 240 x 320 px Display
# 533                  2500 mAh Battery  2.4 inches, 320 x 240 px Display
# 846                  1900 mAh Battery  2.8 inches, 240 x 320 px Display
# 857  2.8 inches, 240 x 320 px Display                  2 MP Rear Camera
# 873                  2500 mAh Battery  1.8 inches, 480 x 640 px Display
# 917                  1020 mAh Battery  2.4 inches, 240 x 320 px Display
#
#                     camera                               card         os
# 486       2 MP Rear Camera              Memory Card Supported  Bluetooth
# 533     0.3 MP Rear Camera  Memory Card Supported, upto 64 GB  Bluetooth
# 846     0.3 MP Rear Camera  Memory Card Supported, upto 64 GB  Bluetooth
# 857  Memory Card Supported          Memory Card Not Supported  Bluetooth
# 873       2 MP Rear Camera  Memory Card Supported, upto 48 GB  Bluetooth
# 917     0.3 MP Rear Camera  Memory Card Supported, upto 32 GB  Bluetooth

# %%
temp_df = df1[df1['os'] == 'Bluetooth']

# %%
df1.loc[temp_df.index,'os'] = np.nan

# %%
df1.loc[temp_df.index,'Bluetooth'] = np.nan

# %%
df1['sim'].value_counts()
# Out:
# sim
# Dual Sim, 3G, 4G, VoLTE, Wi-Fi                               323
# Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC                      268
# Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi                           155
# Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, IR Blaster                54
# Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Blaster           52
# Dual Sim, 3G, 4G, VoLTE, Wi-Fi, NFC                           46
# Dual Sim, 3G, 4G, VoLTE, Wi-Fi, IR Blaster                    46
# Dual Sim                                                      13
# Dual Sim, 3G, 4G, Wi-Fi                                        8
# Dual Sim, 3G, 4G, 5G, VoLTE, Vo5G, Wi-Fi, NFC                  7
# Single Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC                      7
# Dual Sim, 3G, 4G, VoLTE, Wi-Fi, NFC, IR Blaster                5
# Dual Sim, 3G, 4G, VoLTE                                        5
# Single Sim, 3G, 4G, VoLTE, Wi-Fi, NFC                          4
# Single Sim                                                     4
# Dual Sim, 3G, 4G, 5G, VoLTE, Vo5G, Wi-Fi                       3
# Single Sim, 3G, 4G, VoLTE, Wi-Fi                               3
# Dual Sim, 3G, Wi-Fi                                            2
# Dual Sim, 3G, 4G, Wi-Fi, NFC                                   2
# Single Sim, 3G, 4G, Wi-Fi, NFC                                 1
# Single Sim, 3G, 4G, 5G, VoLTE, Wi-Fi                           1
# Dual Sim, Wi-Fi                                                1
# Dual Sim, 4G, VoLTE, Wi-Fi                                     1
# Dual Sim, 3G, 4G, 5G, VoLTE, Vo5G, Wi-Fi, IR Blaster           1
# Single Sim, 3G, 4G, Wi-Fi                                      1
# Dual Sim, 3G, 4G                                               1
# Dual Sim, 3G, 4G, 5G, VoLTE, Vo5G, Wi-Fi, NFC, IR Blaster      1
# Name: count, dtype: int64

# %%
df1['processor'].value_counts()
# Out:
# processor
# Dimensity 700 5G, Octa Core, 2.2 GHz Processor      29
# Helio P35, Octa Core, 2.3 GHz Processor             27
# Snapdragon 8+ Gen1, Octa Core, 3.2 GHz Processor    26
# Snapdragon 8 Gen2, Octa Core, 3.2 GHz Processor     23
# Snapdragon 680, Octa Core, 2.4 GHz Processor        23
#                                                     ..
# Snapdragon 425, Quad Core, 1.4 GHz Processor         1
# Snapdragon MSM8909, Quad Core, 1.1 GHz Processor     1
# Snapdragon 720G , Octa Core, 2.3 GHz Processor       1
# Fusion APL1024, Quad Core, 2.37 GHz Processor        1
# Google  Tensor 3, Octa Core Processor                1
# Name: count, Length: 295, dtype: int64

# %%
df1['ram'].value_counts()
# Out:
# ram
# 8 GB RAM, 128 GB inbuilt            267
# 6 GB RAM, 128 GB inbuilt            190
# 4 GB RAM, 64 GB inbuilt             143
# 12 GB RAM, 256 GB inbuilt            70
# 8 GB RAM, 256 GB inbuilt             70
# 4 GB RAM, 128 GB inbuilt             62
# 3 GB RAM, 32 GB inbuilt              37
# 6 GB RAM, 64 GB inbuilt              29
# 2 GB RAM, 32 GB inbuilt              24
# 3 GB RAM, 64 GB inbuilt              15
# 12 GB RAM, 512 GB inbuilt            10
# 6 GB RAM, 256 GB inbuilt              7
# 1 GB RAM, 16 GB inbuilt               6
# 4 GB RAM, 32 GB inbuilt               6
# 16 GB RAM, 256 GB inbuilt             6
# 12 GB RAM, 128 GB inbuilt             4
# 6 GB RAM, 1 TB inbuilt                4
# 6 GB RAM, 512 GB inbuilt              4
# 2 GB RAM, 64 GB inbuilt               4
# 2 GB RAM, 16 GB inbuilt               4
# 1200 mAh Battery                      3
# 64 MB RAM, 128 MB inbuilt             3
# 16 GB RAM, 512 GB inbuilt             3
# 4 GB RAM, 256 GB inbuilt              3
# 8 GB RAM, 512 GB inbuilt              2
# 800 mAh Battery                       2
# 1 GB RAM, 8 GB inbuilt                2
# 3 GB RAM, 16 GB inbuilt               2
# 32 MB RAM, 32 MB inbuilt              2
# T117                                  2
# 4 MB RAM, 4 MB inbuilt                2
# 64 GB inbuilt                         2
# 512 MB RAM, 4 GB inbuilt              2
# Dual Core, 500 MHz Processor          1
# 1000 mAh Battery                      1
# 12 GB RAM, 1 TB inbuilt               1
# 16 MB RAM, 16 MB inbuilt              1
# 1800 mAh Battery                      1
# 4 MB inbuilt                          1
# Unisoc T107                           1
# 48 MB RAM, 48 MB inbuilt              1
# 1470 mAh Battery                      1
# 4 GB RAM, 512 GB inbuilt              1
# 18 GB RAM, 512 GB inbuilt             1
# 2.4 inches, 240 x 320 px Display      1
# 512 GB inbuilt                        1
# Single Core, 208 MHz Processor        1
# 18 GB RAM, 256 GB inbuilt             1
# 1.5 inches, 120 x 120 px Display      1
# 8 MB RAM, 16 MB inbuilt               1
# 1325 mAh Battery                      1
# 200 mAh Battery                       1
# 1750 mAh Battery                      1
# 3.6 inches, 240 x 320 px Display      1
# 128 MB RAM, 48 MB inbuilt             1
# No Wifi                               1
# Name: count, dtype: int64

# %%
df1['battery'].value_counts()
# Out:
# battery
# 5000 mAh Battery with 33W Fast Charging      103
# 5000 mAh Battery with 18W Fast Charging       89
# 5000 mAh Battery                              74
# 5000 mAh Battery with 67W Fast Charging       30
# 5000 mAh Battery with 10W Fast Charging       28
#                                             ...
# 4700 mAh Battery with 45W Fast Charging        1
# 5050 mAh Battery with 10W Fast Charging        1
# 4700 mAh Battery with 200W Fast Charging       1
# 4300 mAh Battery with 120W Fast Charging       1
# 5000 mAh Battery with 68.2W Fast Charging      1
# Name: count, Length: 254, dtype: int64
